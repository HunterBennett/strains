# %% [markdown]
# Hunter Bennett | Glass Lab | Kupffer Strains Project | 07 Feb 2021
#
# This is a re-vamp of the differential peak calling pipeline for comparisons within strains in a given condition (healthy, CCl4, NASH). This pipeline takes in ATAC-seq peaks annotated with H3K27Ac ChIP-seq data (or other histone modified data) from three strains (c57, balb, and aj) and compares each strain to the other pairwise. The main outputs of this file are:
# 1. A homer differential peak file containing each pairwise comparison.
# 2. Scatterplots of each pairwise comparison with significant peaks highlighted.
# 3. Heatmaps of differential peaks across all comparisons to highlight patterns.
# 4. Peak files for GREAT analysis of functional annotations associated with genomic regions.

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('white')

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from plotting_scripts import label_point, pca_rpkm_mat, get_diff_volcano
from homer_preprocessing import read_annotated_peaks, import_homer_diffpeak, pull_comparisons_get_diff

# %%
dataDirectory = ''
workingDirectory = '/home/h1bennet/strains/results/01_Strains_AMLN_ATAC/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# ### Read in raw gene expression files

# %%
df, mat = read_annotated_peaks('./merged_peaks/ann_raw_idr_peaks_merged.txt')

# %%
mat.columns
# Out:
# Index(['/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/00_NCoRWT_Kupffer_ATAC_AMLNDiet_20week_LN203D_JSS_TDT_180425',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/00_NCoRWT_Kupffer_ATAC_AMLNDiet_21week_LN170C_JSS_TDT_160919',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/00_NCoRWT_Kupffer_ATAC_AMLNDiet_30week_LN136C_JSS_TDT_160919',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/00_NCoRWT_Kupffer_ATAC_AMLNDiet_30week_LN141A_JSS_TDT_160921',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/01_balbc_Kupffer_ATAC_AMLNDiet_30week_Balb3C_JSS_TDT_160926',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/01_balbc_Kupffer_ATAC_AMLNDiet_30week_Balb3D_JSS_TDT_160928',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/02_aj_Kupffer_ATAC_AMLNDiet_30week_AJ3A_JSS_TDT_160926',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/02_aj_Kupffer_ATAC_AMLNDiet_30week_AJ3B_JSS_TDT_160926'],
#       dtype='object')

# %% [markdown]
# Select best replicates if filtering in Annotation step supports sample exclusion

# %%
best_reps = [
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/00_NCoRWT_Kupffer_ATAC_AMLNDiet_20week_LN203D_JSS_TDT_180425',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/00_NCoRWT_Kupffer_ATAC_AMLNDiet_21week_LN170C_JSS_TDT_160919',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/01_balbc_Kupffer_ATAC_AMLNDiet_30week_Balb3C_JSS_TDT_160926',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/01_balbc_Kupffer_ATAC_AMLNDiet_30week_Balb3D_JSS_TDT_160928',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/02_aj_Kupffer_ATAC_AMLNDiet_30week_AJ3A_JSS_TDT_160926',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/02_aj_Kupffer_ATAC_AMLNDiet_30week_AJ3B_JSS_TDT_160926']

# %%
# import annotation file
df, mat = read_annotated_peaks('./merged_peaks/ann_raw_idr_peaks_merged.txt')

# pull out selected samples
tst = np.append(np.asarray([True]*18, 'bool'), mat.columns.str.contains('|'.join(best_reps)))
df= df.loc[:, tst]

df.to_csv('./merged_peaks/ann_raw_idr_peaks_merged_samples_filtered.txt', sep='\t')

# %%
df.columns
# Out:
# Index(['Chr', 'Start', 'End', 'Strand', 'Peak Score',
#        'Focus Ratio/Region Size', 'Annotation', 'Detailed Annotation',
#        'Distance to TSS', 'Nearest PromoterID', 'Entrez ID', 'Nearest Unigene',
#        'Nearest Refseq', 'Nearest Ensembl', 'Gene Name', 'Gene Alias',
#        'Gene Description', 'Gene Type',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/00_NCoRWT_Kupffer_ATAC_AMLNDiet_20week_LN203D_JSS_TDT_180425',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/00_NCoRWT_Kupffer_ATAC_AMLNDiet_21week_LN170C_JSS_TDT_160919',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/01_balbc_Kupffer_ATAC_AMLNDiet_30week_Balb3C_JSS_TDT_160926',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/01_balbc_Kupffer_ATAC_AMLNDiet_30week_Balb3D_JSS_TDT_160928',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/02_aj_Kupffer_ATAC_AMLNDiet_30week_AJ3A_JSS_TDT_160926',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/AMLN_30week/02_aj_Kupffer_ATAC_AMLNDiet_30week_AJ3B_JSS_TDT_160926'],
#       dtype='object')

# %%
# %%bash
# source activate deseq_36
# getDiffExpression.pl ./merged_peaks/ann_raw_idr_peaks_merged_samples_filtered.txt \
# 00_c57 00_c57 \
# 01_balbc 01_balbc \
# 02_aj 02_aj \
# -AvsA -peaks > ./merged_peaks/diff_output.txt

# %% [markdown]
# ### Import differential peaks

# %%
diff_peak, peaks, peak_mat, peak_mat_quant = import_homer_diffpeak(
    './merged_peaks/diff_output.txt',
    './merged_peaks/ann_norm_idr_peaks_merged.txt')
# Out:
# annotatePeaks all peaks (61711, 26)
# getDiffExpression selected transcripts (60547, 33)
# annotatePeaks selected peaks (60547, 26)

# %%
# pull out selected samples
cols = np.append(np.asarray([True]*18, 'bool'), peak_mat.columns.str.contains('|'.join(best_reps)))
peaks = peaks.loc[:, tst]
peak_mat = peak_mat.loc[:, peak_mat.columns.str.contains('|'.join(best_reps))]

# %%
comp_dict = pull_comparisons_get_diff(diff_peak, seq_type='Peak')

# %%
comps = ['00_c57 vs. 01_balbc',
         '00_c57 vs. 02_aj',
         '01_balbc vs. 02_aj']

groups = [[[0,1],[2,3]],
         [[0,1],[4,5]],
         [[2,3],[4,5]]]

cols = []
for i in groups:
    subcols = []
    for j in i:
        subcols.extend([k for k in j])
    cols.append(subcols)

colors = [['#4daf4a', '#377eb8'],
          ['#4daf4a', '#e41a1c'],
          ['#377eb8', '#e41a1c']]

# %%
for key, col, group, color in zip(comps, cols, groups, colors):
#     print(key)
#     print('mean calculated using tag dirs:')
#     for colid in peak_mat.iloc[:, col].columns.tolist():
#         print(colid)
#     print('')
    de = comp_dict[key]
    de['logtpm'] = np.log2(peak_mat.iloc[:, col].mean(1)+1)
    de['log10p'] = -np.log10(de.adj_pval + 10**(-50))
    de['g0_mean'] = np.log2(peak_mat.iloc[:, group[0]].mean(1)+1)
    de['g1_mean'] = np.log2(peak_mat.iloc[:, group[1]].mean(1)+1)
    dot_colors = []
    dot_sizes = []
    for index, row in de.iterrows():
        if (row.adj_pval <= 0.05) & (-row.log2fc < 0):
            dot_colors.append(color[1])
            dot_sizes.append(row.log10p)
        elif (row.adj_pval <= 0.05) & (-row.log2fc > 0):
            dot_colors.append(color[0])
            dot_sizes.append(row.log10p)
        else:
            dot_colors.append('grey')
            dot_sizes.append(0.5)
    print(key)
    print('N genes downregulated', np.sum((de.adj_pval <= 0.05) & (de.log2fc < 0)))
    print('N genes upregulated', np.sum((de.adj_pval <= 0.05) & (de.log2fc > 0)))
    print('')
    fig, axs = plt.subplots(1, 2, figsize=(10,6))
    plt.subplots_adjust(wspace=0.5)

    axs[0].set_xlim(left=-np.ceil(np.max(np.abs(de.log2fc))),
                right=np.ceil(np.max(np.abs(de.log2fc))))
    axs[0].scatter(
        x=de.log2fc,
        y=de.logtpm,
        s=dot_sizes, #de.log10p+0.05,
        c=dot_colors)

    axs[0].set_ylabel('Mean Log2(TPM)')
    axs[0].set_xlabel('Log2FC')

    # plot group by group scatter:
    axs[1].scatter(
        x=de.g0_mean,
        y=de.g1_mean,
        s=dot_sizes, #de.log10p+0.05,
        c=dot_colors)
    
    axs[1].set_xlabel(key.split(' vs. ')[0] + ' Mean Tags')
    axs[1].set_ylabel(key.split(' vs. ')[1] + ' Mean Tags')
    
    #set max and min
    countmax = np.max([np.max(de.g0_mean), np.max(de.g1_mean)])
    axs[1].set_xlim([0,np.ceil(countmax)])
    axs[1].set_ylim([0,np.ceil(countmax)])
                      
    plt.savefig('./figures/'+key+'_MAPlot_scatter.png', bbox_inches='tight')
    plt.close()
    
    fig, ax = plt.subplots(figsize=(4,4))
    
        # plot group by group scatter:
    ax.scatter(
        x=de.g0_mean,
        y=de.g1_mean,
        s=dot_sizes, #de.log10p+0.05,
        c=dot_colors)
    
    ax.set_xlabel(key.split(' vs. ')[0] + ' Mean Tags')
    ax.set_ylabel(key.split(' vs. ')[1] + ' Mean Tags')
    
    #set max and min
    countmax = np.max([np.max(de.g0_mean), np.max(de.g1_mean)])
    ax.set_xlim([0,np.ceil(countmax)])
    ax.set_ylim([0,np.ceil(countmax)])
    
    ax.text(0.5,12.5,
        s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc > 1)), key.split(' vs. ')[1]),
        fontsize=14,
        c=color[1])
    ax.text(12.5,0.5,
        s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc < -1)), key.split(' vs. ')[0]),
        fontsize=14,
        c=color[0],
        rotation=-90)
    
    plt.savefig('./figures/'+key+'_scatter.png', bbox_inches='tight')
    plt.close()
# Out:
# 00_c57 vs. 01_balbc
# N genes downregulated 331
# N genes upregulated 195
#
# 00_c57 vs. 02_aj
# N genes downregulated 169
# N genes upregulated 163
#
# 01_balbc vs. 02_aj
# N genes downregulated 190
# N genes upregulated 273

# %% [markdown]
# # Cluster differential enhancers:
# ____
# ### All enhancers

# %%
pval = 0.05
fc = 2

# grab differential enhancers for each comparison
sig_peaks_id = []
for comp in comps:
    de = comp_dict[comp]
    sig_peaks_id.extend(de.loc[((de.adj_pval <= pval) & (np.abs(de.log2fc) >= fc)), :].index.tolist())

sig_peaks_id = np.unique(sig_peaks_id)
print(len(sig_peaks_id))
sig_peaks = peak_mat.reindex(sig_peaks_id)
sig_peaks.columns = sig_peaks.columns.str.split('/').str[-1].str.split(' Tag Count').str[0]

sns.clustermap(np.log2(sig_peaks+1),
               z_score=0,
               cmap='RdBu_r',
               col_colors=['#4daf4a', '#4daf4a',
                           '#377eb8', '#377eb8',
                           '#e41a1c', '#e41a1c'])
plt.savefig('./figures/diff_peaks_clustermap.png', bbox_inches='tight')
# Out:
# 747

# %% [markdown]
# ### distal enhancers only

# %%
pval = 0.05
fc = 1

# grab differential enhancers for each comparison
sig_peaks_id = []
for comp in comps:
    de = comp_dict[comp]
    sig_peaks_bool = (((de.adj_pval <= pval) & (np.abs(de.log2fc) >= fc)) & (np.abs(de.TSS_dist) >= 3000))
    sig_peaks_id.extend(de.loc[sig_peaks_bool, :].index.tolist())

sig_peaks_id = np.unique(sig_peaks_id)
print(len(sig_peaks_id))
sig_peaks = peak_mat.reindex(sig_peaks_id)
sig_peaks.columns = sig_peaks.columns.str.split('/').str[-1].str.split(' Tag Count').str[0]

sns.clustermap(np.log2(sig_peaks+1),
               z_score=0,
               cmap='RdBu_r',
               col_colors=['#4daf4a', '#4daf4a',
                           '#377eb8', '#377eb8',
                           '#e41a1c', '#e41a1c'])
plt.savefig('./figures/diff_peaks_distal_clustermap.png', bbox_inches='tight')
# Out:
# 628

# %% [markdown]
# # Save differential peaks for analysis in GREAT

# %%
if not os.path.isdir('./great_analysis/'):
    os.mkdir('./great_analysis/')
    
if not os.path.isdir('./great_analysis/peak_files/'):
    os.mkdir('./great_analysis/peak_files/')
    
if not os.path.isdir('./great_analysis/bed_files/'):
    os.mkdir('./great_analysis/bed_files/')

# %%
# initialize dict and list of cell types
peak_lists = {}
bg_lists = {}
cells = ['00_c57',
         '01_balbc',
         '02_aj']

# set pvalue and fc thresholds
fc = np.log2(2)
pval = 0.05

for cell in cells:
    print('Analyzing', cell, '...\n')
    
    # set count
    count = 0
    
    for key in comp_dict.keys():
        
        # select get diff data frame.
        df = comp_dict[key]
        
        # check on counter
        print(count)


        # initialize lists if count == 0
        if count == 0:
            # fold change direction depends on the location of the cell in the comparison.
            # if cell is in first position it is reference - so negative log2fc is higher in first position
            if cell in key.split(' vs. ')[0]:
                u = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                i = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                count = count + 1
            # if cell is in second position it is comparison - so positive log2fc is higher in second position
            elif cell in key.split(' vs. ')[1]:
                u = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                i = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                count = count + 1

        else:
            # fold change direction depends on the location of the cell in the comparison.
            # if cell is in first position it is reference - so negative log2fc is higher in first position
            if cell in key.split(' vs. ')[0]:
                u = u.union(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                i = i.intersection(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                count = count + 1
            # if cell is in second position it is comparison - so positive log2fc is higher in second position
            elif cell in key.split(' vs. ')[1]:
                u = u.union(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                i = i.intersection(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                count = count + 1

        
        # summarize iteration
        print('For comp:', key)
        print('Union set at:', len(u), 'peaks')
        print('Intersection set at:', len(i), 'peaks\n')
     
    
        # store lists
        peak_lists[cell+'_union'] = u
        peak_lists[cell+'_intersection'] = i
# Out:
# Analyzing 00_c57 ...
#
# 0
# For comp: 00_c57 vs. 01_balbc
# Union set at: 198 peaks
# Intersection set at: 198 peaks
#
# 1
# For comp: 00_c57 vs. 02_aj
# Union set at: 271 peaks
# Intersection set at: 62 peaks
#
# 2
# For comp: 01_balbc vs. 02_aj
# Union set at: 271 peaks
# Intersection set at: 62 peaks
#
# Analyzing 01_balbc ...
#
# 0
# For comp: 00_c57 vs. 01_balbc
# Union set at: 275 peaks
# Intersection set at: 275 peaks
#
# 1
# For comp: 00_c57 vs. 02_aj
# Union set at: 275 peaks
# Intersection set at: 275 peaks
#
# 1
# For comp: 01_balbc vs. 02_aj
# Union set at: 362 peaks
# Intersection set at: 36 peaks
#
# Analyzing 02_aj ...
#
# 0
# For comp: 00_c57 vs. 01_balbc
# Union set at: 362 peaks
# Intersection set at: 36 peaks
#
# 0
# For comp: 00_c57 vs. 02_aj
# Union set at: 276 peaks
# Intersection set at: 276 peaks
#
# 1
# For comp: 01_balbc vs. 02_aj
# Union set at: 350 peaks
# Intersection set at: 44 peaks

# %% [markdown]
# if np.NaN get introduced into the matrix then it converts 'int' type columns to 'float' type columns, this is not ideal and interferes with downstream peak analysis so we create a dict to change the start and end columns back to integers just in case

# %%
convert_dict = {'Start': int,
                'End': int}

for key in peak_lists.keys():
    # save cell specific promoters
    tmp = diff_peak.reindex(peak_lists[key]).dropna(how='all').iloc[:, :4]
    tmp = tmp.astype(convert_dict)
    tmp.to_csv('./great_analysis/peak_files/'+key+'_poised_peaks.txt',
               sep='\t')

# %% [markdown]
# Save full set of peaks for background

# %%
diff_peak.iloc[:, :4].to_csv(
    './great_analysis/peak_files/all_peaks.txt',
    sep='\t')

# %% [markdown]
# Convert peaks to bed file

# %%
# %%bash
# # delete the existing script file
# rm ./peak_to_bed_great.sh
# # create a script file
# touch ./peak_to_bed_great.sh
# Out:
# rm: cannot remove ‘./peak_to_bed_great.sh’: No such file or directory

# %%
# %%bash
# for peakfile in ./great_analysis/peak_files/*txt;
# do bedfile=${i/act/bg};
# out=${peakfile/.txt/.bed};
# out=${out/peak_files/bed_files}
# echo "pos2bed.pl -o $out $peakfile" >> ./peak_to_bed_great.sh
# done

# %% [markdown]
# # Create bed files for visualization in browser

# %%
if not os.path.isdir('./bed_files/'):
    os.mkdir('./bed_files/')

# %%
# !cp ./great_analysis/bed_files/* ./bed_files/

# %%
# !ls ./bed_files/
# Out:
# 00_c57_intersection_poised_peaks.bed	02_aj_intersection_poised_peaks.bed
# 00_c57_union_poised_peaks.bed		02_aj_union_poised_peaks.bed
# 01_balbc_intersection_poised_peaks.bed	all_peaks.bed
# 01_balbc_union_poised_peaks.bed

# %%
with open('./label_bed.sh', 'w') as f:
    for i in glob.glob('./bed_files/*poised_peaks.bed'):
       
        strain = i.split('/')[-1].split('_')[1]
        settype = i.split('/')[-1].split('_')[2]
        group = "AMLN_30weeks"
        chip = 'ATAC'

        # set track names for upload to ucsc genome browser
        lab = "'track name=\"%s_%s_%s_%s\" description=\"%s %s %s %s DESeq2\"'" % (strain, chip, group, settype, strain, group, chip, settype)
        lab_dist = "'track name=\"%s_%s_%s_%s_distal\" description=\"%s %s %s %s DESeq2\"'" % (strain, chip, group, settype, strain, group, chip, settype)

        # set labels - can't think of a more clever way to do this so we will just
        # use the simple if / else statement to switch labels depending on our 
        # peak set being distal or all
        
        if 'distal' in i:
            l = lab_dist
        else:
            l = lab
        
        label_track = ['echo', l, '|', 'cat', '-',
                       i,
                       '> temp && mv temp',
                       i, '\n']
    
        f.write(' '.join(label_track))
        
    f.close()

# %% [markdown]
# label all peaks post-hoc

# %%
# %%bash
#
# echo 'track name="kupffer_AMLN_30weeks_atac_merged" description="Kupffer AMLN 30 weeks ATAC All Strains"' \
# | cat - ./bed_files/all_peaks.bed \
# > temp && mv temp ./bed_files/all_peaks.bed

# %% [markdown]
# # Check differential peak quality in browser

# %%
# make location column for peak dict (for examining on browser)
diff_peak['location'] = diff_peak.Chr + ':' + diff_peak.Start.map(str) + '-' + diff_peak.End.map(str)

# %%
diff_peak.sort_values('00_c57 vs. 01_balbc adj. p-value', ascending=True).head(20)
# Out:
#                                                       Chr      Start  \
# PeakID
# Merged-chr1-24612753-3                               chr1   24612654
# Merged-chr11-3174397-2                              chr11    3174288
# Merged-chr11-3174071-3                              chr11    3173972
# Merged-chr11-3157018-2                              chr11    3156928
# Merged-chr11-3157612-2                              chr11    3157493
# Merged-chr11-3157920-2                              chr11    3157817
# Merged-chr5-114175771-3                              chr5  114175661
# Merged-chr11-3156728-1                              chr11    3156628
# Merged-chr4_GL456216_random-17329-1  chr4_GL456216_random      17229
# Merged-chr11-3193167-3                              chr11    3193076
# Merged-chr11-3133637-2                              chr11    3133544
# Merged-chr8-127441383-1                              chr8  127441283
# Merged-chr11-3159902-2                              chr11    3159792
# Merged-chr6-92941466-2                               chr6   92941389
# Merged-chr14-105300812-2                            chr14  105300708
# Merged-chr17-3082022-2                              chr17    3081946
# Merged-chr1-173961689-3                              chr1  173961587
# Merged-chr4_GL456216_random-16111-1  chr4_GL456216_random      16011
# Merged-chr11-3132106-2                              chr11    3131998
# Merged-chr17-3084444-1                              chr17    3084344
#
#                                            End Strand   Peak Score  \
# PeakID
# Merged-chr1-24612753-3                24612854      +  1000.000000
# Merged-chr11-3174397-2                 3174488      +  1000.000000
# Merged-chr11-3174071-3                 3174172      +   924.833313
# Merged-chr11-3157018-2                 3157128      +  1000.000000
# Merged-chr11-3157612-2                 3157693      +  1000.000000
# Merged-chr11-3157920-2                 3158017      +  1000.000000
# Merged-chr5-114175771-3              114175861      +   948.666687
# Merged-chr11-3156728-1                 3156828      +  1000.000000
# Merged-chr4_GL456216_random-17329-1      17429      +  1000.000000
# Merged-chr11-3193167-3                 3193276      +  1000.000000
# Merged-chr11-3133637-2                 3133744      +  1000.000000
# Merged-chr8-127441383-1              127441483      +  1000.000000
# Merged-chr11-3159902-2                 3159992      +  1000.000000
# Merged-chr6-92941466-2                92941589      +   851.000000
# Merged-chr14-105300812-2             105300908      +  1000.000000
# Merged-chr17-3082022-2                 3082146      +  1000.000000
# Merged-chr1-173961689-3              173961787      +   866.000000
# Merged-chr4_GL456216_random-16111-1      16211      +  1000.000000
# Merged-chr11-3132106-2                 3132198      +  1000.000000
# Merged-chr17-3084444-1                 3084544      +  1000.000000
#
#                                                                Focus Ratio/Region Size  \
# PeakID
# Merged-chr1-24612753-3               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr11-3174397-2               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr11-3174071-3               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr11-3157018-2               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr11-3157612-2               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr11-3157920-2               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr5-114175771-3              ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr11-3156728-1                   ./atac_peak_files/aj_kupffer_amln_30weeks.idr
# Merged-chr4_GL456216_random-17329-1  ./atac_peak_files/c57bl6j_kupffer_amln_30weeks...
# Merged-chr11-3193167-3               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr11-3133637-2               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr8-127441383-1              ./atac_peak_files/c57bl6j_kupffer_amln_30weeks...
# Merged-chr11-3159902-2               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr6-92941466-2               ./atac_peak_files/balbcj_kupffer_amln_30weeks....
# Merged-chr14-105300812-2             ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr17-3082022-2               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr1-173961689-3              ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr4_GL456216_random-16111-1  ./atac_peak_files/c57bl6j_kupffer_amln_30weeks...
# Merged-chr11-3132106-2               ./atac_peak_files/aj_kupffer_amln_30weeks.idr|...
# Merged-chr17-3084444-1                   ./atac_peak_files/aj_kupffer_amln_30weeks.idr
#
#                                                                Annotation  \
# PeakID
# Merged-chr1-24612753-3                                         Intergenic
# Merged-chr11-3174397-2                 intron (NM_030207, intron 6 of 32)
# Merged-chr11-3174071-3                 intron (NM_030207, intron 6 of 32)
# Merged-chr11-3157018-2                intron (NM_030207, intron 11 of 32)
# Merged-chr11-3157612-2                intron (NM_030207, intron 11 of 32)
# Merged-chr11-3157920-2                    exon (NM_030207, exon 11 of 33)
# Merged-chr5-114175771-3                intron (NM_133904, intron 1 of 51)
# Merged-chr11-3156728-1                intron (NM_030207, intron 12 of 32)
# Merged-chr4_GL456216_random-17329-1  intron (NM_001033326, intron 1 of 6)
# Merged-chr11-3193167-3                 intron (NM_030207, intron 1 of 32)
# Merged-chr11-3133637-2                intron (NM_030207, intron 29 of 32)
# Merged-chr8-127441383-1               intron (NM_033620, intron 20 of 24)
# Merged-chr11-3159902-2                intron (NM_030207, intron 10 of 32)
# Merged-chr6-92941466-2                  intron (NR_015530, intron 1 of 2)
# Merged-chr14-105300812-2                intron (NM_029561, intron 5 of 7)
# Merged-chr17-3082022-2                  intron (NR_003519, intron 1 of 7)
# Merged-chr1-173961689-3                                   TTS (NM_011940)
# Merged-chr4_GL456216_random-16111-1    5' UTR (NM_001033326, exon 1 of 7)
# Merged-chr11-3132106-2                                    TTS (NR_003517)
# Merged-chr17-3084444-1                           promoter-TSS (NR_003519)
#
#                                                       Detailed Annotation  \
# PeakID
# Merged-chr1-24612753-3                                         Intergenic
# Merged-chr11-3174397-2                                    PB1D11|SINE|Alu
# Merged-chr11-3174071-3                 intron (NM_030207, intron 6 of 32)
# Merged-chr11-3157018-2                intron (NM_030207, intron 11 of 32)
# Merged-chr11-3157612-2                intron (NM_030207, intron 11 of 32)
# Merged-chr11-3157920-2                    exon (NM_030207, exon 11 of 33)
# Merged-chr5-114175771-3                intron (NM_133904, intron 1 of 51)
# Merged-chr11-3156728-1                                      ID_B1|SINE|B4
# Merged-chr4_GL456216_random-17329-1  intron (NM_001033326, intron 1 of 6)
# Merged-chr11-3193167-3                                                CpG
# Merged-chr11-3133637-2                intron (NM_030207, intron 29 of 32)
# Merged-chr8-127441383-1               intron (NM_033620, intron 20 of 24)
# Merged-chr11-3159902-2                intron (NM_030207, intron 10 of 32)
# Merged-chr6-92941466-2                  intron (NR_015530, intron 1 of 2)
# Merged-chr14-105300812-2                intron (NM_029561, intron 5 of 7)
# Merged-chr17-3082022-2                  intron (NR_003519, intron 1 of 7)
# Merged-chr1-173961689-3                                   TTS (NM_011940)
# Merged-chr4_GL456216_random-16111-1    5' UTR (NM_001033326, exon 1 of 7)
# Merged-chr11-3132106-2                                    TTS (NR_003517)
# Merged-chr17-3084444-1                           promoter-TSS (NR_003519)
#
#                                      Distance to TSS Nearest PromoterID  ...  \
# PeakID                                                                   ...
# Merged-chr1-24612753-3                      -25317.0          NM_007733  ...
# Merged-chr11-3174397-2                       19075.0          NM_030207  ...
# Merged-chr11-3174071-3                       19391.0          NM_030207  ...
# Merged-chr11-3157018-2                       33007.0          NR_003517  ...
# Merged-chr11-3157612-2                       33572.0          NR_003517  ...
# Merged-chr11-3157920-2                       33896.0          NR_003517  ...
# Merged-chr5-114175771-3                      10243.0          NM_133904  ...
# Merged-chr11-3156728-1                       32707.0          NR_003517  ...
# Merged-chr4_GL456216_random-17329-1           1448.0       NM_001033326  ...
# Merged-chr11-3193167-3                         287.0          NM_030207  ...
# Merged-chr11-3133637-2                        9623.0          NR_003517  ...
# Merged-chr8-127441383-1                     141731.0       NM_001013580  ...
# Merged-chr11-3159902-2                       33571.0          NM_030207  ...
# Merged-chr6-92941466-2                         907.0          NR_015530  ...
# Merged-chr14-105300812-2                     42135.0       NM_001190989  ...
# Merged-chr17-3082022-2                        2137.0          NR_003519  ...
# Merged-chr1-173961689-3                     -19015.0       NM_001302650  ...
# Merged-chr4_GL456216_random-16111-1            230.0       NM_001033326  ...
# Merged-chr11-3132106-2                        8077.0          NR_003517  ...
# Merged-chr17-3084444-1                        -261.0          NR_003519  ...
#
#                                      00_c57 vs. 01_balbc Log2 Fold Change  \
# PeakID
# Merged-chr1-24612753-3                                          -2.397254
# Merged-chr11-3174397-2                                           9.631511
# Merged-chr11-3174071-3                                           3.098436
# Merged-chr11-3157018-2                                           7.768452
# Merged-chr11-3157612-2                                          10.250931
# Merged-chr11-3157920-2                                          10.057164
# Merged-chr5-114175771-3                                          3.292078
# Merged-chr11-3156728-1                                           5.320343
# Merged-chr4_GL456216_random-17329-1                             -9.292251
# Merged-chr11-3193167-3                                           2.117855
# Merged-chr11-3133637-2                                           9.316930
# Merged-chr8-127441383-1                                         -2.976738
# Merged-chr11-3159902-2                                           9.221340
# Merged-chr6-92941466-2                                           5.006476
# Merged-chr14-105300812-2                                         6.767624
# Merged-chr17-3082022-2                                           8.903541
# Merged-chr1-173961689-3                                          3.095453
# Merged-chr4_GL456216_random-16111-1                             -8.813945
# Merged-chr11-3132106-2                                           8.868896
# Merged-chr17-3084444-1                                           3.483886
#
#                                     00_c57 vs. 01_balbc p-value  \
# PeakID
# Merged-chr1-24612753-3                             1.430078e-21
# Merged-chr11-3174397-2                             6.666004e-20
# Merged-chr11-3174071-3                             8.181853e-17
# Merged-chr11-3157018-2                             5.607011e-13
# Merged-chr11-3157612-2                             4.759609e-12
# Merged-chr11-3157920-2                             1.270262e-11
# Merged-chr5-114175771-3                            1.680844e-10
# Merged-chr11-3156728-1                             2.429078e-10
# Merged-chr4_GL456216_random-17329-1                5.394699e-10
# Merged-chr11-3193167-3                             8.077430e-10
# Merged-chr11-3133637-2                             8.301192e-10
# Merged-chr8-127441383-1                            9.557934e-10
# Merged-chr11-3159902-2                             1.035043e-09
# Merged-chr6-92941466-2                             1.660003e-09
# Merged-chr14-105300812-2                           2.836654e-09
# Merged-chr17-3082022-2                             5.025628e-09
# Merged-chr1-173961689-3                            6.188675e-09
# Merged-chr4_GL456216_random-16111-1                7.042689e-09
# Merged-chr11-3132106-2                             8.033614e-09
# Merged-chr17-3084444-1                             8.156187e-09
#
#                                     00_c57 vs. 01_balbc adj. p-value  \
# PeakID
# Merged-chr1-24612753-3                                  8.658120e-17
# Merged-chr11-3174397-2                                  2.017899e-15
# Merged-chr11-3174071-3                                  1.651180e-12
# Merged-chr11-3157018-2                                  8.486632e-09
# Merged-chr11-3157612-2                                  5.763220e-08
# Merged-chr11-3157920-2                                  1.281757e-07
# Merged-chr5-114175771-3                                 1.453762e-06
# Merged-chr11-3156728-1                                  1.838296e-06
# Merged-chr4_GL456216_random-17329-1                     3.629014e-06
# Merged-chr11-3193167-3                                  4.568901e-06
# Merged-chr11-3133637-2                                  4.568901e-06
# Merged-chr8-127441383-1                                 4.820355e-06
# Merged-chr11-3159902-2                                  4.820355e-06
# Merged-chr6-92941466-2                                  7.178682e-06
# Merged-chr14-105300812-2                                1.144930e-05
# Merged-chr17-3082022-2                                  1.901666e-05
# Merged-chr1-173961689-3                                 2.204005e-05
# Merged-chr4_GL456216_random-16111-1                     2.368808e-05
# Merged-chr11-3132106-2                                  2.469000e-05
# Merged-chr17-3084444-1                                  2.469000e-05
#
#                                     00_c57 vs. 02_aj Log2 Fold Change  \
# PeakID
# Merged-chr1-24612753-3                                      -0.451072
# Merged-chr11-3174397-2                                       8.272900
# Merged-chr11-3174071-3                                       2.092486
# Merged-chr11-3157018-2                                       7.172011
# Merged-chr11-3157612-2                                       9.757567
# Merged-chr11-3157920-2                                       9.365155
# Merged-chr5-114175771-3                                      2.015548
# Merged-chr11-3156728-1                                       5.752913
# Merged-chr4_GL456216_random-17329-1                         -8.908556
# Merged-chr11-3193167-3                                       1.509696
# Merged-chr11-3133637-2                                       9.503871
# Merged-chr8-127441383-1                                     -4.299020
# Merged-chr11-3159902-2                                       9.843633
# Merged-chr6-92941466-2                                       1.904892
# Merged-chr14-105300812-2                                     6.044913
# Merged-chr17-3082022-2                                       9.318608
# Merged-chr1-173961689-3                                      1.495559
# Merged-chr4_GL456216_random-16111-1                         -8.430392
# Merged-chr11-3132106-2                                       9.681679
# Merged-chr17-3084444-1                                       2.731861
#
#                                     00_c57 vs. 02_aj p-value  \
# PeakID
# Merged-chr1-24612753-3                          5.964868e-02
# Merged-chr11-3174397-2                          1.755470e-14
# Merged-chr11-3174071-3                          5.661856e-06
# Merged-chr11-3157018-2                          7.028490e-11
# Merged-chr11-3157612-2                          6.629446e-11
# Merged-chr11-3157920-2                          5.025664e-10
# Merged-chr5-114175771-3                         2.732231e-03
# Merged-chr11-3156728-1                          2.726178e-13
# Merged-chr4_GL456216_random-17329-1             2.803355e-09
# Merged-chr11-3193167-3                          1.851948e-05
# Merged-chr11-3133637-2                          2.525154e-10
# Merged-chr8-127441383-1                         5.406344e-12
# Merged-chr11-3159902-2                          5.039509e-11
# Merged-chr6-92941466-2                          1.674514e-01
# Merged-chr14-105300812-2                        5.726972e-07
# Merged-chr17-3082022-2                          6.301218e-10
# Merged-chr1-173961689-3                         4.564711e-02
# Merged-chr4_GL456216_random-16111-1             3.229476e-08
# Merged-chr11-3132106-2                          1.022718e-10
# Merged-chr17-3084444-1                          7.924266e-05
#
#                                     00_c57 vs. 02_aj adj. p-value  \
# PeakID
# Merged-chr1-24612753-3                               7.056787e-01
# Merged-chr11-3174397-2                               2.043297e-10
# Merged-chr11-3174071-3                               1.997023e-03
# Merged-chr11-3157018-2                               2.045220e-07
# Merged-chr11-3157612-2                               2.030634e-07
# Merged-chr11-3157920-2                               1.000565e-06
# Merged-chr5-114175771-3                              1.913445e-01
# Merged-chr11-3156728-1                               2.266544e-09
# Merged-chr4_GL456216_random-17329-1                  3.471269e-06
# Merged-chr11-3193167-3                               5.108040e-03
# Merged-chr11-3133637-2                               5.652265e-07
# Merged-chr8-127441383-1                              2.420295e-08
# Merged-chr11-3159902-2                               1.629385e-07
# Merged-chr6-92941466-2                               1.000000e+00
# Merged-chr14-105300812-2                             2.848704e-04
# Merged-chr17-3082022-2                               1.061242e-06
# Merged-chr1-173961689-3                              6.547536e-01
# Merged-chr4_GL456216_random-16111-1                  2.936704e-05
# Merged-chr11-3132106-2                               2.834292e-07
# Merged-chr17-3084444-1                               1.647059e-02
#
#                                     01_balbc vs. 02_aj Log2 Fold Change  \
# PeakID
# Merged-chr1-24612753-3                                         1.939869
# Merged-chr11-3174397-2                                        -1.370321
# Merged-chr11-3174071-3                                        -1.027903
# Merged-chr11-3157018-2                                        -0.595519
# Merged-chr11-3157612-2                                        -0.500988
# Merged-chr11-3157920-2                                        -0.699794
# Merged-chr5-114175771-3                                       -1.295571
# Merged-chr11-3156728-1                                         0.428803
# Merged-chr4_GL456216_random-17329-1                                 NaN
# Merged-chr11-3193167-3                                        -0.614145
# Merged-chr11-3133637-2                                         0.181177
# Merged-chr8-127441383-1                                       -1.337354
# Merged-chr11-3159902-2                                         0.612914
# Merged-chr6-92941466-2                                        -3.030454
# Merged-chr14-105300812-2                                      -0.749326
# Merged-chr17-3082022-2                                         0.405481
# Merged-chr1-173961689-3                                       -1.650899
# Merged-chr4_GL456216_random-16111-1                                 NaN
# Merged-chr11-3132106-2                                         0.806960
# Merged-chr17-3084444-1                                        -0.754759
#
#                                     01_balbc vs. 02_aj p-value  \
# PeakID
# Merged-chr1-24612753-3                            6.982699e-07
# Merged-chr11-3174397-2                            3.793366e-07
# Merged-chr11-3174071-3                            3.105997e-04
# Merged-chr11-3157018-2                            2.797851e-02
# Merged-chr11-3157612-2                            7.303137e-02
# Merged-chr11-3157920-2                            1.294908e-02
# Merged-chr5-114175771-3                           4.524393e-04
# Merged-chr11-3156728-1                            2.256330e-01
# Merged-chr4_GL456216_random-17329-1               1.000000e+00
# Merged-chr11-3193167-3                            3.116629e-02
# Merged-chr11-3133637-2                            7.295110e-01
# Merged-chr8-127441383-1                           1.405981e-01
# Merged-chr11-3159902-2                            5.401687e-02
# Merged-chr6-92941466-2                            2.509627e-07
# Merged-chr14-105300812-2                          4.015788e-02
# Merged-chr17-3082022-2                            2.028923e-01
# Merged-chr1-173961689-3                           2.437430e-05
# Merged-chr4_GL456216_random-16111-1               1.000000e+00
# Merged-chr11-3132106-2                            1.549051e-01
# Merged-chr17-3084444-1                            4.971851e-02
#
#                                      01_balbc vs. 02_aj adj. p-value  \
# PeakID
# Merged-chr1-24612753-3                                      0.000811
# Merged-chr11-3174397-2                                      0.000507
# Merged-chr11-3174071-3                                      0.060596
# Merged-chr11-3157018-2                                      0.506940
# Merged-chr11-3157612-2                                      0.677419
# Merged-chr11-3157920-2                                      0.382382
# Merged-chr5-114175771-3                                     0.073512
# Merged-chr11-3156728-1                                      0.855805
# Merged-chr4_GL456216_random-17329-1                         1.000000
# Merged-chr11-3193167-3                                      0.525008
# Merged-chr11-3133637-2                                      0.981303
# Merged-chr8-127441383-1                                     0.790438
# Merged-chr11-3159902-2                                      0.624420
# Merged-chr6-92941466-2                                      0.000395
# Merged-chr14-105300812-2                                    0.569864
# Merged-chr17-3082022-2                                      0.840058
# Merged-chr1-173961689-3                                     0.010390
# Merged-chr4_GL456216_random-16111-1                         1.000000
# Merged-chr11-3132106-2                                      0.804582
# Merged-chr17-3084444-1                                      0.610978
#
#                                                              location
# PeakID
# Merged-chr1-24612753-3                         chr1:24612654-24612854
# Merged-chr11-3174397-2                          chr11:3174288-3174488
# Merged-chr11-3174071-3                          chr11:3173972-3174172
# Merged-chr11-3157018-2                          chr11:3156928-3157128
# Merged-chr11-3157612-2                          chr11:3157493-3157693
# Merged-chr11-3157920-2                          chr11:3157817-3158017
# Merged-chr5-114175771-3                      chr5:114175661-114175861
# Merged-chr11-3156728-1                          chr11:3156628-3156828
# Merged-chr4_GL456216_random-17329-1  chr4_GL456216_random:17229-17429
# Merged-chr11-3193167-3                          chr11:3193076-3193276
# Merged-chr11-3133637-2                          chr11:3133544-3133744
# Merged-chr8-127441383-1                      chr8:127441283-127441483
# Merged-chr11-3159902-2                          chr11:3159792-3159992
# Merged-chr6-92941466-2                         chr6:92941389-92941589
# Merged-chr14-105300812-2                    chr14:105300708-105300908
# Merged-chr17-3082022-2                          chr17:3081946-3082146
# Merged-chr1-173961689-3                      chr1:173961587-173961787
# Merged-chr4_GL456216_random-16111-1  chr4_GL456216_random:16011-16211
# Merged-chr11-3132106-2                          chr11:3131998-3132198
# Merged-chr17-3084444-1                          chr17:3084344-3084544
#
# [20 rows x 34 columns]

# %% [markdown]
# ### Balb specific enhancer example

# %% [markdown]
# ![image.png](attachment:image.png)

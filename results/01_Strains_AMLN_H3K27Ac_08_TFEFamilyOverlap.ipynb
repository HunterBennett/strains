# %% [markdown]
# Hunter Bennett | Glass Lab | Kupffer Strains Project | 24 Feb 2021

# %% [markdown]
# The goal of this is to quantify the amount of overlap between the different strain specific peak sets and MITF family binding sites to try and get a sense if MITF signaling could be driving some of the strain specific differences we see in our analysis.

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('white')

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from plotting_scripts import label_point, pca_rpkm_mat, get_diff_volcano
from homer_preprocessing import read_annotated_peaks, import_homer_diffpeak, pull_comparisons_get_diff
from gene_expression_plots import survey_strain_amln_gene_exp, survey_strain_ccl4_gene_exp

# %%
dataDirectory = ''
workingDirectory = '/home/h1bennet/strains/results/01_Strains_AMLN_H3K27Ac/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %%
if not os.path.isdir('./mitf_overlap/'):
    os.mkdir('./mitf_overlap/')

# %% [markdown]
# # Look for overlap
# ____
# It probably makes more sense to look for binding overlap with all three at once. Tried a few different ways and python still can't do 4 way venn diagrams, regardless this seems to be somewhat irrelevant to the main question which is the proportion of peaks in a given set that are cobound by MITF family members

# %%
tfs = np.sort(glob.glob('../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/*'))

# %% [markdown]
# run merge peaks to get actual peak lists

# %%
with open('./mergeMitfTfePeaks_homer.sh', 'w') as f:
    for peak in np.sort(glob.glob('./motif_calling/*act_peaks*')):
        overlap_peaks = ['mergePeaks -d given \\\n',
                         peak, ' \\\n'.join(tfs), '>',
                         peak.replace('motif_calling/',
                                          'mitf_overlap/').replace('.txt',
                                                                   '_overlap.txt'),
                         '\n\n']
        f.write(' '.join(overlap_peaks))
    f.close()

# %%
# !ls ./motif_calling/*peaks.txt
# Out:
# ./motif_calling/00_c57_intersection_act_distal_peaks.txt
# ./motif_calling/00_c57_intersection_act_peaks.txt
# ./motif_calling/00_c57_intersection_bg_distal_peaks.txt
# ./motif_calling/00_c57_intersection_bg_peaks.txt
# ./motif_calling/00_c57_union_act_distal_peaks.txt
# ./motif_calling/00_c57_union_act_peaks.txt
# ./motif_calling/00_c57_union_bg_distal_peaks.txt
# ./motif_calling/00_c57_union_bg_peaks.txt
# ./motif_calling/01_balbc_intersection_act_distal_peaks.txt
# ./motif_calling/01_balbc_intersection_act_peaks.txt
# ./motif_calling/01_balbc_intersection_bg_distal_peaks.txt
# ./motif_calling/01_balbc_intersection_bg_peaks.txt
# ./motif_calling/01_balbc_union_act_distal_peaks.txt
# ./motif_calling/01_balbc_union_act_peaks.txt
# ./motif_calling/01_balbc_union_bg_distal_peaks.txt
# ./motif_calling/01_balbc_union_bg_peaks.txt
# ./motif_calling/02_aj_intersection_act_distal_peaks.txt
# ./motif_calling/02_aj_intersection_act_peaks.txt
# ./motif_calling/02_aj_intersection_bg_distal_peaks.txt
# ./motif_calling/02_aj_intersection_bg_peaks.txt
# ./motif_calling/02_aj_union_act_distal_peaks.txt
# ./motif_calling/02_aj_union_act_peaks.txt
# ./motif_calling/02_aj_union_bg_distal_peaks.txt
# ./motif_calling/02_aj_union_bg_peaks.txt

# %%
with open('./mergeMitfTfePeaks_homer.sh', 'w') as f:
    for peak in np.sort(glob.glob('./active_enhancers/*peaks.txt')):
        overlap_peaks = ['mergePeaks -d given \\\n',
                         peak, ' \\\n'.join(tfs), '>',
                         peak.replace('active_enhancers/',
                                          'mitf_overlap/').replace('.txt',
                                                                   '_overlap.txt'),
                         '\n\n']
        f.write(' '.join(overlap_peaks))

    for peak in np.sort(glob.glob('./motif_calling/*act*peaks*')):
        overlap_peaks = ['mergePeaks -d given \\\n',
                         peak, ' \\\n'.join(tfs), '>',
                         peak.replace('motif_calling/',
                                          'mitf_overlap/').replace('.txt',
                                                                   '_overlap.txt'),
                         '\n\n']    
        f.write(' '.join(overlap_peaks))
        
    f.close()

# %% [markdown]
# # Filter peaks not associated with enhancers

# %%
for i in glob.glob('./mitf_overlap/*overlap.txt'):
    df = pd.read_csv(i,
                 sep='\t',
                 index_col=0)
    df_filt = df.loc[~df.iloc[:, 7].isna(), :]
    df_filt.to_csv(i.replace('overlap.txt', 'overlap_filtered.txt'),
                   sep='\t')

# %% [markdown]
# ## Annotate with gene info

# %%
with open('./annotateMitfTfePeaks_homer.sh', 'w') as f:
    for peak in np.sort(glob.glob('./mitf_overlap/*overlap_filtered*')):
        annotatePeaks = ['annotatePeaks.pl', peak, 'mm10',
                         '>',peak.replace('filtered', 'filtered_anno'),
                         '\n\n']
        f.write(' '.join(annotatePeaks))
    f.close()

# %% [markdown]
# # Quantify overlap
# ____
# This takes advantage of the '-cobound' option in HOMER that creates lists of cobound peaks rather than a gigantic merged peak set

# %%
with open('./mergeMitfTfePeaks_homer_cobound.sh', 'w') as f:
    for peak in np.sort(glob.glob('./motif_calling/*act*')):
        
        cobound = peak.replace('motif_calling/',
                                          'mitf_overlap/').replace('.txt',
                                                                   '_coboundXXX.txt')
        
        overlap_peaks = ['mergePeaks -d given \\\n',
                         '-cobound 3 \\\n',
                         peak, ' \\\n'.join(tfs),
                         '\n']
        f.write(' '.join(overlap_peaks))
        f.write('mv coBoundBy0.txt %s\n' % cobound.replace('XXX', '0'))
        f.write('mv coBoundBy1.txt %s\n' % cobound.replace('XXX', '1'))
        f.write('mv coBoundBy2.txt %s\n' % cobound.replace('XXX', '2'))
        f.write('mv coBoundBy3.txt %s\n\n' % cobound.replace('XXX', '3'))
        
    for peak in np.sort(glob.glob('./active_enhancers/*peaks.txt')):
        
        cobound = peak.replace('active_enhancers/',
                                          'mitf_overlap/').replace('.txt',
                                                                   '_coboundXXX.txt')
        
        overlap_peaks = ['mergePeaks -d given \\\n',
                         '-cobound 3 \\\n',
                         peak, ' \\\n'.join(tfs),
                         '\n']
        f.write(' '.join(overlap_peaks))
        f.write('mv coBoundBy0.txt %s\n' % cobound.replace('XXX', '0'))
        f.write('mv coBoundBy1.txt %s\n' % cobound.replace('XXX', '1'))
        f.write('mv coBoundBy2.txt %s\n' % cobound.replace('XXX', '2'))
        f.write('mv coBoundBy3.txt %s\n\n' % cobound.replace('XXX', '3'))

    f.close()

# %%
# !bash mergeMitfTfePeaks_homer_cobound.sh
# Out:
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/00_c57_intersection_act_distal_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	811	4.79	-3024.40
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	844	4.80	-3147.49
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	723	4.86	-2686.72
#
# 	Co-bound by 0 peaks: 624
# 	Co-bound by 1 peaks: 143
# 	Co-bound by 2 peaks: 150
# 	Co-bound by 3 peaks: 645 (max: 645 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/00_c57_intersection_act_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	944	4.73	-3458.93
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	989	4.75	-3635.28
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	830	4.79	-3020.06
#
# 	Co-bound by 0 peaks: 823
# 	Co-bound by 1 peaks: 180
# 	Co-bound by 2 peaks: 189
# 	Co-bound by 3 peaks: 735 (max: 735 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/00_c57_union_act_distal_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	1985	4.80	-7468.13
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	2034	4.79	-7597.14
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	1730	4.85	-6454.47
#
# 	Co-bound by 0 peaks: 1512
# 	Co-bound by 1 peaks: 353
# 	Co-bound by 2 peaks: 397
# 	Co-bound by 3 peaks: 1534 (max: 1534 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/00_c57_union_act_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	2329	4.70	-8471.33
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	2420	4.71	-8779.45
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	2008	4.75	-7242.66
#
# 	Co-bound by 0 peaks: 2125
# 	Co-bound by 1 peaks: 472
# 	Co-bound by 2 peaks: 516
# 	Co-bound by 3 peaks: 1751 (max: 1751 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/01_balbc_intersection_act_distal_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	75	3.80	-194.67
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	80	3.84	-209.04
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	54	3.65	-127.88
#
# 	Co-bound by 0 peaks: 281
# 	Co-bound by 1 peaks: 25
# 	Co-bound by 2 peaks: 29
# 	Co-bound by 3 peaks: 42 (max: 42 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/01_balbc_intersection_act_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	97	3.72	-236.50
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	105	3.79	-269.76
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	63	3.49	-141.06
#
# 	Co-bound by 0 peaks: 391
# 	Co-bound by 1 peaks: 38
# 	Co-bound by 2 peaks: 37
# 	Co-bound by 3 peaks: 51 (max: 51 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/01_balbc_union_act_distal_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	592	4.01	-1666.34
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	634	4.05	-1807.12
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	430	3.89	-1152.42
#
# 	Co-bound by 0 peaks: 1693
# 	Co-bound by 1 peaks: 202
# 	Co-bound by 2 peaks: 196
# 	Co-bound by 3 peaks: 354 (max: 354 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/01_balbc_union_act_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	755	3.94	-2070.69
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	843	4.03	-2396.28
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	543	3.81	-1405.34
#
# 	Co-bound by 0 peaks: 2331
# 	Co-bound by 1 peaks: 289
# 	Co-bound by 2 peaks: 263
# 	Co-bound by 3 peaks: 442 (max: 442 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/02_aj_intersection_act_distal_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	48	4.07	-136.63
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	48	4.03	-131.32
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	33	3.81	-77.02
#
# 	Co-bound by 0 peaks: 126
# 	Co-bound by 1 peaks: 16
# 	Co-bound by 2 peaks: 16
# 	Co-bound by 3 peaks: 27 (max: 27 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/02_aj_intersection_act_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	60	3.99	-168.06
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	62	3.99	-170.97
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	40	3.71	-91.34
#
# 	Co-bound by 0 peaks: 173
# 	Co-bound by 1 peaks: 21
# 	Co-bound by 2 peaks: 24
# 	Co-bound by 3 peaks: 31 (max: 31 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/02_aj_union_act_distal_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	659	4.15	-1967.33
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	661	4.12	-1943.64
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	545	4.14	-1580.89
#
# 	Co-bound by 0 peaks: 1583
# 	Co-bound by 1 peaks: 182
# 	Co-bound by 2 peaks: 198
# 	Co-bound by 3 peaks: 429 (max: 429 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./motif_calling/02_aj_union_act_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	802	4.04	-2280.55
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	845	4.06	-2417.83
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	667	4.04	-1858.23
#
# 	Co-bound by 0 peaks: 2179
# 	Co-bound by 1 peaks: 254
# 	Co-bound by 2 peaks: 265
# 	Co-bound by 3 peaks: 510 (max: 510 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./active_enhancers/AJ_active_distal_enhancer_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	6981	4.64	-25023.70
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	7097	4.62	-24964.26
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	5823	4.65	-20292.06
#
# 	Co-bound by 0 peaks: 7043
# 	Co-bound by 1 peaks: 1668
# 	Co-bound by 2 peaks: 1729
# 	Co-bound by 3 peaks: 4925 (max: 4925 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./active_enhancers/AJ_active_enhancer_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	12028	4.40	-39790.32
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	13391	4.47	-44852.03
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	9434	4.34	-29788.88
#
# 	Co-bound by 0 peaks: 17336
# 	Co-bound by 1 peaks: 4198
# 	Co-bound by 2 peaks: 3911
# 	Co-bound by 3 peaks: 7611 (max: 7611 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./active_enhancers/BALBcJ_active_distal_enhancer_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	6974	4.63	-24929.48
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	7120	4.62	-24970.58
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	5771	4.63	-20027.14
#
# 	Co-bound by 0 peaks: 7168
# 	Co-bound by 1 peaks: 1687
# 	Co-bound by 2 peaks: 1772
# 	Co-bound by 3 peaks: 4878 (max: 4878 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./active_enhancers/BALBcJ_active_enhancer_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	12068	4.39	-39824.32
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	13499	4.47	-45159.60
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	9370	4.33	-29446.70
#
# 	Co-bound by 0 peaks: 17643
# 	Co-bound by 1 peaks: 4279
# 	Co-bound by 2 peaks: 3992
# 	Co-bound by 3 peaks: 7558 (max: 7558 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./active_enhancers/C57Bl6J_active_distal_enhancer_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	7131	4.74	-26481.94
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	7239	4.72	-26350.12
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	5994	4.75	-21657.39
#
# 	Co-bound by 0 peaks: 5875
# 	Co-bound by 1 peaks: 1550
# 	Co-bound by 2 peaks: 1673
# 	Co-bound by 3 peaks: 5156 (max: 5156 effective total)
# 	Max distance to merge: direct overlap required (-d given)
# 	Calculating co-bound peaks relative to reference: ./active_enhancers/C57Bl6J_active_enhancer_peaks.txt
#
# 	Comparing peaks: (peakfile, overlapping peaks, logRatio(obs/expected), logP)
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/mitf_bmdm_merged.txt	12149	4.47	-41161.88
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfe3_bmdm_merged.txt	13459	4.53	-46026.67
# 		../99_TFE_Family_ChIP_PeakCalling_test/merged_peaks/tfeb_bmdm_merged.txt	9597	4.42	-31114.03
#
# 	Co-bound by 0 peaks: 15714
# 	Co-bound by 1 peaks: 4010
# 	Co-bound by 2 peaks: 3821
# 	Co-bound by 3 peaks: 7851 (max: 7851 effective total)

# %% [markdown]
# # View number of overlapping peaks per set as pie chart

# %% [markdown]
# Use nifty file rows script from stack overflow
# https://stackoverflow.com/questions/845058/how-to-get-line-count-of-a-large-file-cheaply-in-python

# %%
def file_len(fname):
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1

# %% [markdown]
# ## Run for unique peak sets

# %% [markdown]
# ### Set loop variables
# _____
# 1. comparisons to iterate through
# 2. colors
# 3. labels
# 4. whether to explode

# %%
peaksets = ['00_c57_intersection_act_peaks',
               '01_balbc_intersection_act_peaks',
               '02_aj_intersection_act_peaks',
               '00_c57_union_act_peaks',
               '01_balbc_union_act_peaks',
               '02_aj_union_act_peaks',
               '00_c57_intersection_act_distal_peaks',
               '01_balbc_intersection_act_distal_peaks',
               '02_aj_intersection_act_distal_peaks',
               '00_c57_union_act_distal_peaks',
               '01_balbc_union_act_distal_peaks',
               '02_aj_union_act_distal_peaks']
labels = ['Co-Bound by 0 TFs', 'Co-Bound by 1 TFs', 'Co-Bound by 2 TFs', 'Co-Bound by 3 TFs']
colors = ['#969696', '#fd8d3c', '#e6550d', '#a63603']
explode = [0, 0, 0, 0]

# %%
for ps in peaksets:    
    n_peak_list = []
    for cb in np.sort(glob.glob('./mitf_overlap/'+ps+'*cobound*')):
        n_peak_list.append(file_len(cb) - 1)

    fig, ax = plt.subplots(figsize=(6,6))
    ax.pie(n_peak_list,
           explode=explode,
           labels=labels,
           colors=colors,
           autopct = '%.1f');
    ax.set_title(ps)
    plt.savefig('./figures/mitf_family_overlap_'+ps+'.png',
                bbox_inches='tight')
    plt.close()

# %%
fig, axs = plt.subplots(4,3, figsize=(20,15))
plt.subplots_adjust(wspace=1)
for ps, ax in zip(peaksets, axs.flat):    
    n_peak_list = []
    for cb in np.sort(glob.glob('./mitf_overlap/'+ps+'*cobound*')):
        n_peak_list.append(file_len(cb) - 1)
    ax.pie(n_peak_list,
           explode=explode,
           labels=labels,
           colors=colors,
           autopct = '%.1f');
    ax.set_title(ps)
plt.savefig('./figures/mitf_family_overlap_all.png',
            bbox_inches='tight')
# plt.close()

# %% [markdown]
# ## Run for all active enhancer sets

# %%
peaksets = ['AJ_active_distal_enhancer_peaks',
            'AJ_active_enhancer_peaks',
            'BALBcJ_active_distal_enhancer_peaks',
            'BALBcJ_active_enhancer_peaks',
            'C57Bl6J_active_distal_enhancer_peaks',
            'C57Bl6J_active_enhancer_peaks']

labels = ['Co-Bound by 0 TFs', 'Co-Bound by 1 TFs', 'Co-Bound by 2 TFs', 'Co-Bound by 3 TFs']
colors = ['#969696', '#fd8d3c', '#e6550d', '#a63603']
explode = [0, 0, 0, 0]

# %%
for ps in peaksets:    
    n_peak_list = []
    for cb in np.sort(glob.glob('./mitf_overlap/'+ps+'*cobound*')):
        n_peak_list.append(file_len(cb) - 1)

    fig, ax = plt.subplots(figsize=(6,6))
    ax.pie(n_peak_list,
           explode=explode,
           labels=labels,
           colors=colors,
           autopct = '%.1f');
    ax.set_title(ps)
    plt.savefig('./figures/mitf_family_overlap_'+ps+'.png',
                bbox_inches='tight')
    plt.close()

# %%
fig, axs = plt.subplots(3,2, figsize=(15,15))
plt.subplots_adjust(wspace=1)
for ps, ax in zip(peaksets, axs.flat):    
    n_peak_list = []
    for cb in np.sort(glob.glob('./mitf_overlap/'+ps+'*cobound*')):
        n_peak_list.append(file_len(cb) - 1)
    ax.pie(n_peak_list,
           explode=explode,
           labels=labels,
           colors=colors,
           autopct = '%.1f');
    ax.set_title(ps)
plt.savefig('./figures/mitf_family_overlap_all_active_enhancers.png',
            bbox_inches='tight')
# plt.close()

# %% [markdown]
# How many balb specific TFE peaks overlap a motif mutation?

# %% [markdown]
# Old ways to iterate through merge peaks

# %%
# with open('./mergeMitfTfePeaks_homer.sh', 'w') as f:
#     for tf in np.sort(glob.glob('../99_TFE_Family_ChIP_PeakCalling/merged_peaks/*')):
#         tfname = tf.split('/')[-1].split('_')[0]
#         for peak in np.sort(glob.glob('./motif_calling/*act*')):
#             overlap_peaks = ['mergePeaks -d given \\\n',
#                              '-matrix',
#                              peak.replace('motif_calling/',
#                                               'mitf_overlap/'+tfname+'_').replace('.txt'
#                                                                               ,'')+' \\\n',
#                              peak, tf, '>',
#                              peak.replace('motif_calling/',
#                                               'mitf_overlap/'+tfname+'_').replace('.txt',
#                                                                               '_overlap.txt'),
#                              '\n\n']
#             f.write(' '.join(overlap_peaks))

#     f.close()

# %%
# with open('./mergeMitfTfePeaks_homer.sh', 'w') as f:
#     for peak in np.sort(glob.glob('./motif_calling/*act*')):
#         overlap_peaks = ['mergePeaks -d given \\\n',
#                          '-matrix',
#                          peak.replace('motif_calling/',
#                                           'mitf_overlap/').replace('.txt','')+' \\\n',
#                          '-venn',
#                          peak.replace('motif_calling/',
#                                           'mitf_overlap/').replace('.txt','_venn.txt')+' \\\n',
#                          peak, ' \\\n'.join(tfs), '>',
#                          peak.replace('motif_calling/',
#                                           'mitf_overlap/').replace('.txt',
#                                                                    '_overlap.txt'),
#                          '\n\n']
#         f.write(' '.join(overlap_peaks))

#     f.close()

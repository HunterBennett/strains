# %% [markdown]
# Hunter Bennett | Glass Lab | Kupffer Strains Project | April 20 2021
#
# This notebook will do a basic analysis of motif enrichment in "poised" or "active" enhancers over a generic background

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 400
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('ticks')
# get matplotlib to save readable fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from plotting_scripts import label_point, pca_rpkm_mat, get_diff_volcano
from homer_preprocessing import read_annotated_peaks, import_homer_diffpeak, pull_comparisons_get_diff
from gene_expression_plots import survey_strain_amln_gene_exp, survey_strain_ccl4_gene_exp

# %%
dataDirectory = ''
workingDirectory = '/home/h1bennet/strains/results/06_Strains_Control_H3K27Ac/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# # Call motifs using homer
# ____
# Main difference here is we are just using a general background. This is because most enhancers are 'poised' by our definition within a strain so we just want to get an idea for the enrichment of different motifs within the open chromatin of each sample

# %%
strain_dict = {'C57Bl6J': 'c57bl6j',
               'BALBcJ': 'balbcj',
               'AJ': 'aj'}

# %%
with open('./findMotifs_active.sh', 'w') as f:
    for peakfile in np.sort(glob.glob('./active_enhancers/*peaks.txt')):
        strain = peakfile.split('/')[-1].split('_')[0]
        call = ['/home/vlink/code/marge/bin/MMARGE.pl', 'denovo_motifs',
                peakfile, 'mm10', peakfile.replace('_peaks.txt', '_motifs'),
                '-len 8,10,12,14,16', '-fg_strain', strain_dict[strain],
                '-bg_strain', strain_dict[strain], '-p 8\n\n']
        f.write(' '.join(call))
    f.close()

# %% [markdown]
# # Aggregate results - Homer

# %%
glob.glob('./active_enhancers/*/knownResults.txt')
# Out:
# ['./active_enhancers/AJ_active_enhancer_motifs/knownResults.txt',
#  './active_enhancers/C57Bl6J_active_distal_enhancer_motifs/knownResults.txt',
#  './active_enhancers/AJ_active_distal_enhancer_motifs/knownResults.txt',
#  './active_enhancers/BALBcJ_active_enhancer_motifs/knownResults.txt',
#  './active_enhancers/C57Bl6J_active_enhancer_motifs/knownResults.txt',
#  './active_enhancers/BALBcJ_active_distal_enhancer_motifs/knownResults.txt']

# %%
frame[frame.index.str.contains('STAT')].iloc[:, 1]
# Out:
# Motif Name
# STAT4(Stat)/CD4-Stat4-ChIP-Seq(GSE22104)/Homer           1e-33
# STAT6(Stat)/CD4-Stat6-ChIP-Seq(GSE22104)/Homer           1e-16
# STAT1(Stat)/HelaS3-STAT1-ChIP-Seq(GSE12782)/Homer        1e-15
# STAT5(Stat)/mCD4+-Stat5-ChIP-Seq(GSE12346)/Homer         1e-13
# STAT6(Stat)/Macrophage-Stat6-ChIP-Seq(GSE38377)/Homer    1e-12
# Name: P-value, dtype: object

# %%
known_motif_pval_dict = {}
for f in np.sort(glob.glob('./active_enhancers/*/knownResults.txt')):
    # read in signifance values using pandas
    frame = pd.read_csv(f, sep='\t', index_col=0)
    
    # remove duplicates
    frame = frame[~frame.index.duplicated(keep='first')]
    pval = frame.iloc[:, 2]
    
    # extract name of sample
    sample = f.split('/')[2]
    
    # store in dict
    known_motif_pval_dict[sample] = pval    
    
# create data frame
known_motif_pval_frame = pd.DataFrame(known_motif_pval_dict)

# sort by average p value
known_motif_pval_frame = known_motif_pval_frame.reindex(known_motif_pval_frame.mean(axis=1).sort_values().index.tolist())

known_motif_pval_frame.to_csv('./homer_known_motifs_log.txt', sep='\t')

# %%
sns.clustermap(
    -known_motif_pval_frame.loc[(known_motif_pval_frame <=-5).any(axis=1),
                                ~known_motif_pval_frame.columns.str.contains('distal')].head(20),
    cmap='Reds',
    linewidths=1,
    linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#e41a1c', '#377eb8', '#4daf4a'],
    figsize=(4,12))

plt.savefig('./figures/homer_active_enhancers_motif_clustermap.png',
            bbox_inches='tight')

# %%
sns.clustermap(
    -known_motif_pval_frame.loc[(known_motif_pval_frame <=-5).any(axis=1),
                                known_motif_pval_frame.columns.str.contains('distal')].head(20),
    cmap='Reds',
    linewidths=1,
    linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#e41a1c', '#377eb8', '#4daf4a'],
    figsize=(4,12))

plt.savefig('./figures/homer_active_distal_enhancers_motif_clustermap.png',
            bbox_inches='tight')

# %% [markdown]
# # Stat specific motif enrichment

# %%
log10_frame = np.log10(np.e**(known_motif_pval_frame)+10**-100)

# %%
sns.heatmap(
    -log10_frame.loc[log10_frame.index.str.contains('STAT'),
                                log10_frame.columns.str.contains('distal')].head(20),
    cmap='Reds',
    linewidths=1,
    linecolor='k',
    annot=True,
    fmt=".2f",
    cbar_kws={'label': '-log10(pval)'},
    # col_cluster=False,
    square=True)
    # center=0,
    # ax=ax,
    # col_colors=['#e41a1c', '#377eb8', '#4daf4a'],
    # figsize=(4,6))

plt.savefig('./figures/homer_active_distal_enhancers_stat_motif_clustermap.pdf',
            bbox_inches='tight')

# %% [markdown]
# # Scatter plot comparing motif scores across strains
#
# Goal here is to get a sense for how motif scores (compared to randomly generated background) vary across strain active enhancers

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.scatter(np.log2(-known_motif_pval_frame['C57Bl6J_active_distal_enhancer_motifs']+1),
           np.log2(-known_motif_pval_frame['AJ_active_distal_enhancer_motifs']+1),
           s=0.5,
           c='r')
ax.scatter(np.log2(-known_motif_pval_frame['C57Bl6J_active_distal_enhancer_motifs']+1),
           np.log2(-known_motif_pval_frame['BALBcJ_active_distal_enhancer_motifs']+1),
           s=0.5,
           c='b')

# %%
known_motif_pval_frame.corr()
# Out:
#                                        AJ_active_distal_enhancer_motifs  \
# AJ_active_distal_enhancer_motifs                               1.000000
# AJ_active_enhancer_motifs                                      0.987483
# BALBcJ_active_distal_enhancer_motifs                           0.998708
# BALBcJ_active_enhancer_motifs                                  0.983429
# C57Bl6J_active_distal_enhancer_motifs                          0.998723
# C57Bl6J_active_enhancer_motifs                                 0.980777
#
#                                        AJ_active_enhancer_motifs  \
# AJ_active_distal_enhancer_motifs                        0.987483
# AJ_active_enhancer_motifs                               1.000000
# BALBcJ_active_distal_enhancer_motifs                    0.989204
# BALBcJ_active_enhancer_motifs                           0.997751
# C57Bl6J_active_distal_enhancer_motifs                   0.988961
# C57Bl6J_active_enhancer_motifs                          0.997522
#
#                                        BALBcJ_active_distal_enhancer_motifs  \
# AJ_active_distal_enhancer_motifs                                   0.998708
# AJ_active_enhancer_motifs                                          0.989204
# BALBcJ_active_distal_enhancer_motifs                               1.000000
# BALBcJ_active_enhancer_motifs                                      0.985841
# C57Bl6J_active_distal_enhancer_motifs                              0.998458
# C57Bl6J_active_enhancer_motifs                                     0.983241
#
#                                        BALBcJ_active_enhancer_motifs  \
# AJ_active_distal_enhancer_motifs                            0.983429
# AJ_active_enhancer_motifs                                   0.997751
# BALBcJ_active_distal_enhancer_motifs                        0.985841
# BALBcJ_active_enhancer_motifs                               1.000000
# C57Bl6J_active_distal_enhancer_motifs                       0.984976
# C57Bl6J_active_enhancer_motifs                              0.998720
#
#                                        C57Bl6J_active_distal_enhancer_motifs  \
# AJ_active_distal_enhancer_motifs                                    0.998723
# AJ_active_enhancer_motifs                                           0.988961
# BALBcJ_active_distal_enhancer_motifs                                0.998458
# BALBcJ_active_enhancer_motifs                                       0.984976
# C57Bl6J_active_distal_enhancer_motifs                               1.000000
# C57Bl6J_active_enhancer_motifs                                      0.983206
#
#                                        C57Bl6J_active_enhancer_motifs
# AJ_active_distal_enhancer_motifs                             0.980777
# AJ_active_enhancer_motifs                                    0.997522
# BALBcJ_active_distal_enhancer_motifs                         0.983241
# BALBcJ_active_enhancer_motifs                                0.998720
# C57Bl6J_active_distal_enhancer_motifs                        0.983206
# C57Bl6J_active_enhancer_motifs                               1.000000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(7,3))
plt.subplots_adjust(wspace=.5)
ax1.scatter(np.log2(-known_motif_pval_frame['C57Bl6J_active_distal_enhancer_motifs']+1),
           np.log2(-known_motif_pval_frame['AJ_active_distal_enhancer_motifs']+1),
           s=0.5,
           c='r')
ax1.set_xlabel('C57BL/6J')
ax1.set_ylabel('AJ')
ax1.text(0,12,
         'R^2=%.3f' % known_motif_pval_frame.corr().loc['C57Bl6J_active_distal_enhancer_motifs',
                                                        'AJ_active_distal_enhancer_motifs']**2)

ax2.scatter(np.log2(-known_motif_pval_frame['C57Bl6J_active_distal_enhancer_motifs']+1),
           np.log2(-known_motif_pval_frame['BALBcJ_active_distal_enhancer_motifs']+1),
           s=0.5,
           c='b')
ax2.set_xlabel('C57BL/6J')
ax2.set_ylabel('BALB/cJ')
ax2.text(0,12,
         'R^2=%.3f' % known_motif_pval_frame.corr().loc['C57Bl6J_active_distal_enhancer_motifs',
                                                        'BALBcJ_active_distal_enhancer_motifs']**2)
# Out:
# Text(0, 12, 'R^2=0.997')

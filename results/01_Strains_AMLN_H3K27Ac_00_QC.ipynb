# %% [markdown]
# Hunter Bennett | Glass Lab | Kupffer Strains Project | 07 February 2021

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('white')

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df

# %% [markdown]
# Set working directory

# %%
dataDirectory = '/home/h1bennet/strains/data/H3K27Ac/AMLN_30week/'
workingDirectory = '/home/h1bennet/strains/results/01_Strains_AMLN_H3K27Ac/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# # Quality control

# %%
qc = ngs_qc(dataDirectory, 'atac')
# Out:
# /home/h1bennet/strains/data/H3K27Ac/AMLN_30week//
# ./AMLN_30week_qc/

# %%
qc
# Out:
#                                                     uniquePositions  \
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579A_1...       13746159.0
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579C_1...       13880759.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579A_180423       16813438.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423       16342081.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb1...       13037890.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb6...       15280448.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb14D...       18058951.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB...       16669080.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15A_18...       12563447.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15B_18...       14427883.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ6A_180423       16493481.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423        19085091.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15B_180423        16713121.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ6A_180423         18566836.0
#
#                                                     fragmentLengthEstimate  \
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579A_1...                   173.0
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579C_1...                   181.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579A_180423                    80.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423                   185.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb1...                   160.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb6...                   173.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb14D...                    82.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB...                    80.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15A_18...                    94.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15B_18...                   170.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ6A_180423                   170.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423                     80.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15B_180423                     80.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ6A_180423                     187.0
#
#                                                     tagsPerBP  clonality  \
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579A_1...   0.006878      1.364
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579C_1...   0.007054      1.385
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579A_180423   0.006948      1.127
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423   0.006420      1.071
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb1...   0.007764      1.621
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb6...   0.007965      1.419
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb14D...   0.007776      1.172
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB...   0.006638      1.084
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15A_18...   0.006166      1.336
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15B_18...   0.007629      1.440
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ6A_180423   0.008035      1.326
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423    0.007966      1.136
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15B_180423    0.006684      1.089
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ6A_180423     0.007238      1.061
#
#                                                     GC_Content  totalReads  \
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579A_1...       0.453  21738087.0
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579C_1...       0.446  22542305.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579A_180423       0.395  23663600.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423       0.399  21864785.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb1...      -1.000  24616602.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb6...      -1.000  24340798.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb14D...      -1.000  26432968.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB...      -1.000  22385106.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15A_18...      -1.000  20519668.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15B_18...      -1.000  24008195.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ6A_180423      -1.000  24954704.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423       -1.000  27375649.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15B_180423       -1.000  22578351.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ6A_180423        -1.000  24650712.0
#
#                                                     uniquelyMappedReads  \
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579A_1...           17357147.0
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579C_1...           17647817.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579A_180423           16469958.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423           15196305.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb1...           19472207.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb6...           20709043.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb14D...           18614981.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB...           15850678.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15A_18...           15151721.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15B_18...           19438465.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ6A_180423           20424677.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423            19008545.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15B_180423            15964429.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ6A_180423             17215976.0
#
#                                                     multiMappedReads  \
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579A_1...         3941014.0
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579C_1...         4430301.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579A_180423         6771654.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423         6280354.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb1...         4564542.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb6...         3034347.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb14D...         7218510.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB...         6056665.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15A_18...         4776898.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15B_18...         3966619.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ6A_180423         3948031.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423          7739284.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15B_180423          6129451.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ6A_180423           6881083.0
#
#                                                     unmappedReads  \
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579A_1...       439926.0
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579C_1...       464187.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579A_180423       421988.0
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423       388126.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb1...       579853.0
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb6...       597408.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb14D...       599477.0
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB...       477763.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15A_18...       591049.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15B_18...       603111.0
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ6A_180423       581996.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423        627820.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15B_180423        484471.0
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ6A_180423         553653.0
#
#                                                     uniquelyMappedFraction  \
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579A_1...                0.798467
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579C_1...                0.782875
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579A_180423                0.696004
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423                0.695013
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb1...                0.791019
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb6...                0.850796
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb14D...                0.704233
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB...                0.708090
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15A_18...                0.738400
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15B_18...                0.809660
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ6A_180423                0.818470
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423                 0.694360
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15B_180423                 0.707068
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ6A_180423                  0.698397
#
#                                                     mappedFraction
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579A_1...        0.979762
# 00_C57_Kupffer_H3K27Ac_AMLNDiet_20weeks_C579C_1...        0.979408
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579A_180423        0.982167
# 00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423        0.982249
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb1...        0.976445
# 01_balbc_Kupffer_H3K27Ac_AMLNDiet_30weeks_Balb6...        0.975457
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb14D...        0.977321
# 01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB...        0.978657
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15A_18...        0.971196
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ15B_18...        0.974879
# 02_aj_Kupffer_H3K27Ac_AMLNDiet_30weeks_AJ6A_180423        0.976678
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423         0.977066
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15B_180423         0.978543
# 02_aj_Kupffer_input_AMLNDiet_30weeks_AJ6A_180423          0.977540

# %% [markdown]
# ### Plot tag count distribution

# %%
tds = glob.glob(dataDirectory+'/*')
tds = np.sort(tds)

fig, axs = plt.subplots(2,3, figsize=(15, 10), sharex=True, sharey=True)

for ax, td in zip(axs.flatten(), tds):
    df = pd.read_csv(td+'/tagCountDistribution.txt', sep='\t', index_col=0)
    df.loc[1:10, :].plot.bar(ax=ax, legend=False)
    ax.set_xlabel('Tags per position')
    ax.set_ylabel('Fraction of Positions')
    ax.set_title(td.split('/')[-1].split('_AL')[0], fontsize=8)

# %% [markdown]
# ### make browser hub (run on command line for now)

# %% [markdown]
# |Colors:|      |
# |------|------|
# |AJ:| 228,26,28|
# |Balb:| 55,126,184|
# |C57:| 77,175,74|

# %%
# makeMultiWigHub.pl hrb_strains_h3k27ac_amln_30week mm10 -force -color \
# 77,175,74 77,175,74 77,175,74 77,175,74 \
# 55,126,184 55,126,184 55,126,184 55,126,184 \
# 228,26,28 228,26,28 228,26,28 228,26,28 228,26,28 228,26,28 \
# -d /gpfs/data01/glasslab/home/h1bennet/strains/data/H3K27Ac/AMLN_30week/*

# %% [markdown]
#  Based on the browser tracks and the qc for these samples this experiment will probably need to be redone.

# %% [markdown]
# # Find peaks

# %%
# %%bash
# # delete the existing script file
# rm ./peakCalling_homer.sh
# # create a script file
# touch ./peakCalling_homer.sh
#
# # if directories don't exist, create them
# if [ ! -d ./peak_files/ ]; then mkdir ./peak_files; fi

# %%
# set input directory
with open('./peakCalling_homer.sh', 'w') as f:
    for tagdir in os.listdir(dataDirectory):
        if '00_C57' in tagdir:
            inputdir='00_C57_Kupffer_input_AMLNDiet_20weeks_C579C_180423'
        elif '01_balb' in tagdir:
            inputdir='01_balbc_Kupffer_input_AMLNDiet_30weeks_Balb6AB_180423'
        elif '02_aj' in tagdir:
            inputdir='02_aj_Kupffer_input_AMLNDiet_30weeks_AJ15A_180423'
        
        find_peaks_fw = ['findPeaks', dataDirectory + '/' + tagdir,
                          '-i', dataDirectory + '/' + inputdir,
                          '-size 1000 -minDist 2500',
                          '-o',
                          workingDirectory + '/peak_files/' + tagdir + '_fixedwidth_peaks.tsv',
                          '&', '\n']
        find_peaks = ['findPeaks', dataDirectory + '/' + tagdir,
                          '-i', dataDirectory + '/' + inputdir, '-region',
                          '-size 1000 -minDist 2500',
                          '-o',
                          workingDirectory + '/peak_files/' + tagdir + '_variablewidth_peaks.tsv',
                          '&', '\n']
        # write commands to file
        f.write(' '.join(find_peaks_fw))
        f.write(' '.join(find_peaks))

# %%
peak_stats={}

for td in np.sort(glob.glob('./peak_files/*H3K27Ac*')):

    peak_dict = {'total_peaks': 0,
                 'ip_eff': 0.0,
                 'peaks_filt_input': 0,
                 'peaks_filt_local': 0,
                 'peaks_filt_clonal':0}

    with open(td, 'r') as f:
        for line in f.readlines():
            if "total peaks" in line:
                peak_dict['total_peaks'] = int(line.split(' = ')[-1])
            if "Approximate IP efficiency" in line:
                peak_dict['ip_eff'] = float(line.replace('%\n', '').split(' = ')[-1])
            if "Putative peaks filtered by input" in line:
                peak_dict['peaks_filt_input'] = int(line.split(' = ')[-1])
            if "Putative peaks filtered by local signal" in line:
                peak_dict['peaks_filt_local'] = int(line.split(' = ')[-1])
            if "Putative peaks filtered for being too clonal" in line:
                peak_dict['peaks_filt_clonal'] = int(line.split(' = ')[-1])
                
    peak_stats[td] = peak_dict
            
df = pd.DataFrame(peak_stats).T

# %%
df
# Out:
#                                                     total_peaks  ip_eff  \
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...      17706.0   21.93
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...      20208.0   43.22
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...      16945.0   19.10
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...      19756.0   38.52
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...      17919.0   20.97
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...      19927.0   40.33
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...      20618.0   32.93
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...      22712.0   65.33
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...      11548.0    8.92
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...      13935.0   18.53
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...      17626.0   23.33
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...      19895.0   47.35
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...      18300.0   26.03
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...      20614.0   52.23
#
#                                                     peaks_filt_input  \
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...            4281.0
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...             437.0
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...            4496.0
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...             460.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...            3282.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...             297.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...            3734.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...             409.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...            4819.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...             501.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...            5452.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...             523.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...            5828.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...             569.0
#
#                                                     peaks_filt_local  \
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...            4326.0
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...               0.0
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...            4473.0
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...               0.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...            3847.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...               0.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...            4758.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...               0.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...            3160.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...               0.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...            4485.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...               0.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...            4569.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...               0.0
#
#                                                     peaks_filt_clonal
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...                0.0
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...                0.0
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...                0.0
# ./peak_files/00_C57_Kupffer_H3K27Ac_AMLNDiet_20...                0.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...                0.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...                5.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...                2.0
# ./peak_files/01_balbc_Kupffer_H3K27Ac_AMLNDiet_...                7.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...                0.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...                1.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...                0.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...                2.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...                1.0
# ./peak_files/02_aj_Kupffer_H3K27Ac_AMLNDiet_30w...                7.0

# %% [markdown]
# ### Write to files

# %%
df.loc[df.index.str.contains('variable'), :].to_csv('./variablewidth_peak_table.txt', sep='\t')
df.loc[df.index.str.contains('fixed'), :].to_csv('./fixedwidth_peak_table.txt', sep='\t')

# %% [markdown]
# Short utility notebook for looking into mutations at certain loci between the strains using MARGE

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns

# import custom functions
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from homer_preprocessing import read_homer_gene_exp, read_annotated_peaks

# %%
dataDirectory = ''
workingDirectory = '/home/h1bennet/strains/results/99b_Survey_Strain_mutations/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %%
tpm = read_homer_gene_exp('/home/ttroutman/strainsKupffer/rnaKupfferNASH/rnaQuan/HOMER.rawTPM.txt',
                          gene_name_index=True)
# tpm_mat = tpm_mat.loc[:, tpm_mat.columns.str.contains('control')]

# %% [markdown]
# Select genes of interest

# %%
genes_of_interest = ['Lepr', 'Lep', 'Mitf', 'Tfe3', 'Tfeb', 'Tfec']

# %%
tpm.loc[genes_of_interest, :].iloc[:, :4].to_csv(
    './210403_genes.txt',
    sep='\t')

# %%
tpm.head()
# Out:
#                  chr      start        end strand  Length  Copies  \
# gene
# Mia2           chr12   59095800   59190175      +  4538.0       1
# Abraxas1        chr5  100804802  100820935      -  2488.0       1
# March1          chr8   66386301   66471637      +  3936.0       1
# Mob3b           chr4   34949074   35157484      -  6024.0       1
# 1810034E14Rik  chr13   64248700   64268145      +  1799.0       1
#
#                                            Annotation/Divergence  \
# gene
# Mia2           Mia2|Ctage5|D12Bwg0579e|Mea6|Mgea|Mgea6|-|12 2...
# Abraxas1       Abraxas1|3830405G04Rik|5630400M01Rik|AI506069|...
# March1         March1|2900024D24Rik|BB085186|-|8|8 B3.1|prote...
# Mob3b          Mob3b|8430436F23Rik|A430018A01Rik|Mobkl2b|-|4 ...
# 1810034E14Rik                   1810034E14Rik|-|-|13|13 B3|ncRNA
#
#                AJ_Kupffer_RNA_AJ01C_HBENN_l20201208_TACCGAGG_CCTGAACT.aj.star_shifted_from_AJ.sa  \
# gene
# Mia2                                                      60.108
# Abraxas1                                                   2.581
# March1                                                    57.909
# Mob3b                                                      1.531
# 1810034E14Rik                                              0.974
#
#                AJ_Kupffer_RNA_AJ01D_HBENN_l20201208_CGTTAGAA_TTCAGGTC.aj.star_shifted_from_AJ.sa  \
# gene
# Mia2                                                      67.625
# Abraxas1                                                   4.101
# March1                                                    79.025
# Mob3b                                                      2.496
# 1810034E14Rik                                              1.119
#
#                BALBC_Kupffer_RNA_BALB01C_HBENN_l20201208_AGCCTCAT_AGTAGAGA.balbcj.star_shifted_from_BALBCJ.sa  \
# gene
# Mia2                                                      57.602
# Abraxas1                                                   2.813
# March1                                                    55.064
# Mob3b                                                      3.912
# 1810034E14Rik                                              0.458
#
#                ...  \
# gene           ...
# Mia2           ...
# Abraxas1       ...
# March1         ...
# Mob3b          ...
# 1810034E14Rik  ...
#
#                aj_KupfferTotal_RNA_polyA_AMLNDiet_30week_AJ3A_JSSTDT_16_09_2  \
# gene
# Mia2                                                      60.632
# Abraxas1                                                   2.803
# March1                                                   112.092
# Mob3b                                                      2.454
# 1810034E14Rik                                              1.562
#
#                aj_KupfferTotal_RNA_polyA_AMLNDiet_30week_AJ3B_JSSTDT_16_09_2  \
# gene
# Mia2                                                      53.128
# Abraxas1                                                   3.057
# March1                                                    98.156
# Mob3b                                                      2.114
# 1810034E14Rik                                              0.917
#
#                aj_KupfferTotal_RNA_polyA_AMLNDiet_30week_AJ3c_JSS_TDT_16_09_2  \
# gene
# Mia2                                                      26.630
# Abraxas1                                                   1.566
# March1                                                    51.064
# Mob3b                                                      1.031
# 1810034E14Rik                                              1.259
#
#                balbc_KupfferTotal_RNA_polyA_AMLNDiet_30week_Balb3B_JSSTDT_16_09_2  \
# gene
# Mia2                                                      64.113
# Abraxas1                                                   2.611
# March1                                                   103.723
# Mob3b                                                      3.396
# 1810034E14Rik                                              0.808
#
#                balbc_KupfferTotal_RNA_polyA_AMLNDiet_30week_Balb3C_JSSTDT_16_09_2  \
# gene
# Mia2                                                      45.735
# Abraxas1                                                   3.043
# March1                                                    73.842
# Mob3b                                                      3.078
# 1810034E14Rik                                              1.133
#
#                balbc_KupfferTotal_RNA_polyA_AMLNDiet_30week_Balb3d_JSS_TDT_16_09_2  \
# gene
# Mia2                                                      43.279
# Abraxas1                                                   2.577
# March1                                                    55.775
# Mob3b                                                      2.522
# 1810034E14Rik                                              1.740
#
#                NCoRWT_KupfferTim4Pos_RNA_polyA_AMLNDiet_30week_LN144B_JSS_TDT_16_10_2  \
# gene
# Mia2                                                      39.245
# Abraxas1                                                   2.701
# March1                                                    58.059
# Mob3b                                                      1.165
# 1810034E14Rik                                              1.818
#
#                NCoRWT_KupfferTim4Pos_RNA_polyA_AMLNDiet_30week_LN146C_JSS_TDT_16_10_2  \
# gene
# Mia2                                                      33.394
# Abraxas1                                                   2.288
# March1                                                    64.909
# Mob3b                                                      0.533
# 1810034E14Rik                                              1.549
#
#                NCoRWT_KupfferTim4Pos_RNA_polyA_AMLNDiet_30week_LN146D_JSS_TDT_16_10_2  \
# gene
# Mia2                                                      39.861
# Abraxas1                                                   1.751
# March1                                                    58.102
# Mob3b                                                      0.925
# 1810034E14Rik                                              2.315
#
#                NCoRWT_KupfferTim4Pos_RNA_polyA_AMLNDiet_30week_LN152B_JSS_TDT_16_10_2
# gene
# Mia2                                                      35.133
# Abraxas1                                                   2.201
# March1                                                    53.251
# Mob3b                                                      0.987
# 1810034E14Rik                                              1.745
#
# [5 rows x 24 columns]

# %% [markdown]
#     MMARGE.pl annotate_mutations -file ./210403_genes.txt \
#     -ind balbcj, aj
#
#     MMARGE.pl annotate_mutations -genome mm10 -exons -file ./210403_genes.txt \
#     -ind balbcj, aj

# %% [markdown]
# # Check exons

# %%
tpm_refseq = read_homer_gene_exp('/home/ttroutman/strainsKupffer/rnaKupfferNASH/rnaQuan/HOMER.rawTPM.txt',
                          gene_name_index=False)

# %%
tpm_refseq.loc[tpm_refseq['Annotation/Divergence'].str.contains('Lepr\|'), :]
# Out:
#                chr      start        end strand  Length  Copies  \
# refseqID
# NM_001122899  chr4  101717407  101813667      +  5518.0       1
#
#                                           Annotation/Divergence  \
# refseqID
# NM_001122899  Lepr|LEPROT|Leprb|Modb1|OB-RGRP|Obr|db|diabete...
#
#               AJ_Kupffer_RNA_AJ01C_HBENN_l20201208_TACCGAGG_CCTGAACT.aj.star_shifted_from_AJ.sa  \
# refseqID
# NM_001122899                                             14.771
#
#               AJ_Kupffer_RNA_AJ01D_HBENN_l20201208_CGTTAGAA_TTCAGGTC.aj.star_shifted_from_AJ.sa  \
# refseqID
# NM_001122899                                             20.947
#
#               BALBC_Kupffer_RNA_BALB01C_HBENN_l20201208_AGCCTCAT_AGTAGAGA.balbcj.star_shifted_from_BALBCJ.sa  \
# refseqID
# NM_001122899                                            144.931
#
#               ...  \
# refseqID      ...
# NM_001122899  ...
#
#               aj_KupfferTotal_RNA_polyA_AMLNDiet_30week_AJ3A_JSSTDT_16_09_2  \
# refseqID
# NM_001122899                                             10.169
#
#               aj_KupfferTotal_RNA_polyA_AMLNDiet_30week_AJ3B_JSSTDT_16_09_2  \
# refseqID
# NM_001122899                                              8.287
#
#               aj_KupfferTotal_RNA_polyA_AMLNDiet_30week_AJ3c_JSS_TDT_16_09_2  \
# refseqID
# NM_001122899                                             11.375
#
#               balbc_KupfferTotal_RNA_polyA_AMLNDiet_30week_Balb3B_JSSTDT_16_09_2  \
# refseqID
# NM_001122899                                             39.444
#
#               balbc_KupfferTotal_RNA_polyA_AMLNDiet_30week_Balb3C_JSSTDT_16_09_2  \
# refseqID
# NM_001122899                                             19.404
#
#               balbc_KupfferTotal_RNA_polyA_AMLNDiet_30week_Balb3d_JSS_TDT_16_09_2  \
# refseqID
# NM_001122899                                             65.375
#
#               NCoRWT_KupfferTim4Pos_RNA_polyA_AMLNDiet_30week_LN144B_JSS_TDT_16_10_2  \
# refseqID
# NM_001122899                                               1.67
#
#               NCoRWT_KupfferTim4Pos_RNA_polyA_AMLNDiet_30week_LN146C_JSS_TDT_16_10_2  \
# refseqID
# NM_001122899                                               4.27
#
#               NCoRWT_KupfferTim4Pos_RNA_polyA_AMLNDiet_30week_LN146D_JSS_TDT_16_10_2  \
# refseqID
# NM_001122899                                              1.672
#
#               NCoRWT_KupfferTim4Pos_RNA_polyA_AMLNDiet_30week_LN152B_JSS_TDT_16_10_2
# refseqID
# NM_001122899                                              2.179
#
# [1 rows x 24 columns]

# %%
exons = pd.read_csv('/home/ttroutman/strainsKupffer/annotateMutations/mm10_exons',
                    sep='\t',
                    index_col=0)

# %%
exons.loc[exons.index.str.contains('NM_001122899')]
# Out:
#                                                      chr      start  \
# RepeatID (cmd=analyzeRepeats.pl rna mm10 -count...
# NM_001122899--Part1                                 chr4  101717407
# NM_001122899--Part2                                 chr4  101728010
# NM_001122899--Part3                                 chr4  101728030
# NM_001122899--Part4                                 chr4  101733267
# NM_001122899--Part5                                 chr4  101735560
# NM_001122899--Part6                                 chr4  101745511
# NM_001122899--Part7                                 chr4  101750287
# NM_001122899--Part8                                 chr4  101752061
# NM_001122899--Part9                                 chr4  101764861
# NM_001122899--Part10                                chr4  101765304
# NM_001122899--Part11                                chr4  101768047
# NM_001122899--Part12                                chr4  101771297
# NM_001122899--Part13                                chr4  101772836
# NM_001122899--Part14                                chr4  101774201
# NM_001122899--Part15                                chr4  101779905
# NM_001122899--Part16                                chr4  101782545
# NM_001122899--Part17                                chr4  101789263
# NM_001122899--Part18                                chr4  101790801
# NM_001122899--Part19                                chr4  101791995
# NM_001122899--Part20                                chr4  101811348
# NM_001122899--Part21                                chr4  101811366
#
#                                                           end strand  \
# RepeatID (cmd=analyzeRepeats.pl rna mm10 -count...
# NM_001122899--Part1                                 101717938      +
# NM_001122899--Part2                                 101728029      +
# NM_001122899--Part3                                 101728069      +
# NM_001122899--Part4                                 101733596      +
# NM_001122899--Part5                                 101735683      +
# NM_001122899--Part6                                 101745716      +
# NM_001122899--Part7                                 101750429      +
# NM_001122899--Part8                                 101752205      +
# NM_001122899--Part9                                 101765151      +
# NM_001122899--Part10                                101765421      +
# NM_001122899--Part11                                101768246      +
# NM_001122899--Part12                                101771445      +
# NM_001122899--Part13                                101772995      +
# NM_001122899--Part14                                101774283      +
# NM_001122899--Part15                                101780121      +
# NM_001122899--Part16                                101782727      +
# NM_001122899--Part17                                101789358      +
# NM_001122899--Part18                                101790906      +
# NM_001122899--Part19                                101792070      +
# NM_001122899--Part20                                101811365      +
# NM_001122899--Part21                                101813667      +
#
#                                                            Code  Divergence  \
# RepeatID (cmd=analyzeRepeats.pl rna mm10 -count...
# NM_001122899--Part1                                 E:101717407           0
# NM_001122899--Part2                                 E:101728010           0
# NM_001122899--Part3                                 E:101728030           0
# NM_001122899--Part4                                 E:101733267           0
# NM_001122899--Part5                                 E:101735560           0
# NM_001122899--Part6                                 E:101745511           0
# NM_001122899--Part7                                 E:101750287           0
# NM_001122899--Part8                                 E:101752061           0
# NM_001122899--Part9                                 E:101764861           0
# NM_001122899--Part10                                E:101765304           0
# NM_001122899--Part11                                E:101768047           0
# NM_001122899--Part12                                E:101771297           0
# NM_001122899--Part13                                E:101772836           0
# NM_001122899--Part14                                E:101774201           0
# NM_001122899--Part15                                E:101779905           0
# NM_001122899--Part16                                E:101782545           0
# NM_001122899--Part17                                E:101789263           0
# NM_001122899--Part18                                E:101790801           0
# NM_001122899--Part19                                E:101791995           0
# NM_001122899--Part20                                E:101811348           0
# NM_001122899--Part21                                E:101811366           0
#
#                                                     FullStart    FullEnd
# RepeatID (cmd=analyzeRepeats.pl rna mm10 -count...
# NM_001122899--Part1                                 101717407  101813667
# NM_001122899--Part2                                 101717407  101813667
# NM_001122899--Part3                                 101717407  101813667
# NM_001122899--Part4                                 101717407  101813667
# NM_001122899--Part5                                 101717407  101813667
# NM_001122899--Part6                                 101717407  101813667
# NM_001122899--Part7                                 101717407  101813667
# NM_001122899--Part8                                 101717407  101813667
# NM_001122899--Part9                                 101717407  101813667
# NM_001122899--Part10                                101717407  101813667
# NM_001122899--Part11                                101717407  101813667
# NM_001122899--Part12                                101717407  101813667
# NM_001122899--Part13                                101717407  101813667
# NM_001122899--Part14                                101717407  101813667
# NM_001122899--Part15                                101717407  101813667
# NM_001122899--Part16                                101717407  101813667
# NM_001122899--Part17                                101717407  101813667
# NM_001122899--Part18                                101717407  101813667
# NM_001122899--Part19                                101717407  101813667
# NM_001122899--Part20                                101717407  101813667
# NM_001122899--Part21                                101717407  101813667

# %%
exons.loc[exons.index.str.contains('NM_001122899')].to_csv(
    './lepr_exons.txt',
    sep='\t')

# %% [markdown]
#     MMARGE.pl annotate_mutations -file ./lepr_exons.txt \
#     -ind balbcj, aj

# %% [markdown]
# # Look in annotated Leptin receptor ATAC Peaks

# %%
df, mat = read_annotated_peaks(
    '/gpfs/data01/glasslab/home/h1bennet/strains/results/00_Strains_Control_H3K27Ac/merged_peaks/ann_norm_kc_control_atac_peaks_all.txt')

# %%
df.loc[df['Nearest PromoterID']=='NM_001122899', :].iloc[:, :4].to_csv(
    './lepr_atac_peaks.txt',
    sep='\t')

# %% [markdown]
#     MMARGE.pl annotate_mutations -file ./lepr_atac_peaks.txt \
#     -ind balbcj, aj

# %% [markdown]
# # Look in ATAC peaks from browser

# %%
chrs = ['chr4', 'chr4', 'chr4']
start = [101740726, 101741039, 101714403]
end = [101743066, 101722450, 101717403]
strand = ['+', '+', '+']

# %%
df = pd.DataFrame([chrs, start, end, strand],
                  index=['chr', 'start', 'end', 'strand'],
                  columns=['intron_1', 'intron_2', 'tss']).T.to_csv(
    './lepr_custom_peaks.txt',
    sep='\t')

# %% [markdown]
#     MMARGE.pl annotate_mutations -file ./lepr_custom_peaks.txt \
#     -ind balbcj, aj

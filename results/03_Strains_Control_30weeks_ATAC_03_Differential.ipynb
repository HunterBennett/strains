# %% [markdown]
# Hunter Bennett | Glass Lab | Kupffer Strains Project | 08 Feb 2021
#
# This is a re-vamp of the differential peak calling pipeline for comparisons within strains in a given condition (healthy, CCl4, NASH). This pipeline takes in ATAC-seq peaks annotated with H3K27Ac ChIP-seq data (or other histone modified data) from three strains (c57, balb, and aj) and compares each strain to the other pairwise. The main outputs of this file are:
# 1. A homer differential peak file containing each pairwise comparison.
# 2. Scatterplots of each pairwise comparison with significant peaks highlighted.
# 3. Heatmaps of differential peaks across all comparisons to highlight patterns.
# 4. Peak files for GREAT analysis of functional annotations associated with genomic regions.

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('white')

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from plotting_scripts import label_point, pca_rpkm_mat, get_diff_volcano
from homer_preprocessing import read_annotated_peaks, import_homer_diffpeak, pull_comparisons_get_diff

# %%
dataDirectory = ''
workingDirectory = '/home/h1bennet/strains/results/03_Strains_Control_30weeks_ATAC/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# ### Read in raw gene expression files

# %%
df, mat = read_annotated_peaks('./merged_peaks/ann_raw_idr_peaks_merged.txt')

# %%
mat.columns
# Out:
# Index(['/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/00_NCoRWT_Kupffer_ATAC_ControlDiet_30week_LN134B_JSS_TDT_160921',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/00_NCoRWT_Kupffer_ATAC_ControlDiet_30week_LN134D_JSS_TDT_160921',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/01_balbc_Kupffer_ATAC_ControlDiet_30week_Balb1A_JSS_TDT_160926',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/01_balbc_Kupffer_ATAC_ControlDiet_30week_Balb1B_JSS_TDT_160926',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/02_aj_Kupffer_ATAC_ControlDiet_30week_AJ1B_JSS_TDT_160926',
#        '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/02_aj_Kupffer_ATAC_ControlDiet_30week_AJ1C_JSS_TDT_160928'],
#       dtype='object')

# %%
best_reps = ['/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/00_NCoRWT_Kupffer_ATAC_ControlDiet_30week_LN134B_JSS_TDT_160921',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/00_NCoRWT_Kupffer_ATAC_ControlDiet_30week_LN134D_JSS_TDT_160921',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/01_balbc_Kupffer_ATAC_ControlDiet_30week_Balb1A_JSS_TDT_160926',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/01_balbc_Kupffer_ATAC_ControlDiet_30week_Balb1B_JSS_TDT_160926',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/02_aj_Kupffer_ATAC_ControlDiet_30week_AJ1B_JSS_TDT_160926',
       '/gpfs/data01/glasslab/home/h1bennet/strains/data/ATAC/control_30week/02_aj_Kupffer_ATAC_ControlDiet_30week_AJ1C_JSS_TDT_160928']

# %%
# import annotation file
df, mat = read_annotated_peaks('./merged_peaks/ann_raw_idr_peaks_merged.txt')

# pull out selected samples
tst = np.append(np.asarray([True]*18, 'bool'), mat.columns.str.contains('|'.join(best_reps)))
df= df.loc[:, tst]

df.to_csv('./merged_peaks/ann_raw_idr_peaks_merged_samples_filtered.txt', sep='\t')

# %%
# %%bash
# source activate deseq_36
# getDiffExpression.pl ./merged_peaks/ann_raw_idr_peaks_merged_samples_filtered.txt \
# 00_c57 00_c57 \
# 01_balbc 01_balbc \
# 02_aj 02_aj \
# -AvsA -peaks > ./merged_peaks/diff_output.txt
# Out:
# 	Treating input as file generated by annotatePeaks.pl (-peaks)
#
# 	Performing variance stabalization (rlog)...
#
#
# 	Warning: getDiffExpression.pl now defaults to DESeq2 for calculations (instead of edgeR)
#
# 	Using DESeq2 to calculate differential expression/enrichment...
# 	Output Stats 00_c57 vs. 01_balbc:
# 		Total Genes: 54547
# 		Total Up-regulated in 01_balbc vs. 00_c57: 240 (0.440%) [log2fold>1, FDR<0.05]
# 		Total Dn-regulated in 01_balbc vs. 00_c57: 195 (0.357%) [log2fold<-1, FDR<0.05]
# 	Output Stats 00_c57 vs. 02_aj:
# 		Total Genes: 54547
# 		Total Up-regulated in 02_aj vs. 00_c57: 353 (0.647%) [log2fold>1, FDR<0.05]
# 		Total Dn-regulated in 02_aj vs. 00_c57: 692 (1.269%) [log2fold<-1, FDR<0.05]
# 	Output Stats 01_balbc vs. 02_aj:
# 		Total Genes: 54547
# 		Total Up-regulated in 02_aj vs. 01_balbc: 77 (0.141%) [log2fold>1, FDR<0.05]
# 		Total Dn-regulated in 02_aj vs. 01_balbc: 165 (0.302%) [log2fold<-1, FDR<0.05]

# %% [markdown]
# ### Import differential peaks

# %%
diff_peak, peaks, peak_mat, peak_mat_quant = import_homer_diffpeak(
    './merged_peaks/diff_output.txt',
    './merged_peaks/ann_norm_idr_peaks_merged.txt')
# Out:
# annotatePeaks all peaks (55569, 24)
# getDiffExpression selected transcripts (54547, 33)
# annotatePeaks selected peaks (54547, 24)

# %%
# pull out selected samples
cols = np.append(np.asarray([True]*18, 'bool'), peak_mat.columns.str.contains('|'.join(best_reps)))
peaks = peaks.loc[:, tst]
peak_mat = peak_mat.loc[:, peak_mat.columns.str.contains('|'.join(best_reps))]

# %%
comp_dict = pull_comparisons_get_diff(diff_peak, seq_type='Peak')

# %%
comps = ['00_c57 vs. 01_balbc',
         '00_c57 vs. 02_aj',
         '01_balbc vs. 02_aj']

groups = [[[0,1],[2,3]],
         [[0,1],[4,5]],
         [[2,3],[4,5]]]

cols = []
for i in groups:
    subcols = []
    for j in i:
        subcols.extend([k for k in j])
    cols.append(subcols)

colors = [['#4daf4a', '#377eb8'],
          ['#4daf4a', '#e41a1c'],
          ['#377eb8', '#e41a1c']]

# %%
for key, col, group, color in zip(comps, cols, groups, colors):
#     print(key)
#     print('mean calculated using tag dirs:')
#     for colid in peak_mat.iloc[:, col].columns.tolist():
#         print(colid)
#     print('')
    de = comp_dict[key]
    de['logtpm'] = np.log2(peak_mat.iloc[:, col].mean(1)+1)
    de['log10p'] = -np.log10(de.adj_pval + 10**(-50))
    de['g0_mean'] = np.log2(peak_mat.iloc[:, group[0]].mean(1)+1)
    de['g1_mean'] = np.log2(peak_mat.iloc[:, group[1]].mean(1)+1)
    dot_colors = []
    dot_sizes = []
    for index, row in de.iterrows():
        if (row.adj_pval <= 0.05) & (-row.log2fc < 0):
            dot_colors.append(color[1])
            dot_sizes.append(row.log10p)
        elif (row.adj_pval <= 0.05) & (-row.log2fc > 0):
            dot_colors.append(color[0])
            dot_sizes.append(row.log10p)
        else:
            dot_colors.append('grey')
            dot_sizes.append(0.5)
    print(key)
    print('N genes downregulated', np.sum((de.adj_pval <= 0.05) & (de.log2fc < 0)))
    print('N genes upregulated', np.sum((de.adj_pval <= 0.05) & (de.log2fc > 0)))
    print('')
    fig, axs = plt.subplots(1, 2, figsize=(10,6))
    plt.subplots_adjust(wspace=0.5)

    axs[0].set_xlim(left=-np.ceil(np.max(np.abs(de.log2fc))),
                right=np.ceil(np.max(np.abs(de.log2fc))))
    axs[0].scatter(
        x=de.log2fc,
        y=de.logtpm,
        s=dot_sizes, #de.log10p+0.05,
        c=dot_colors)

    axs[0].set_ylabel('Mean Log2(TPM)')
    axs[0].set_xlabel('Log2FC')

    # plot group by group scatter:
    axs[1].scatter(
        x=de.g0_mean,
        y=de.g1_mean,
        s=dot_sizes, #de.log10p+0.05,
        c=dot_colors)
    
    axs[1].set_xlabel(key.split(' vs. ')[0] + ' Mean Tags')
    axs[1].set_ylabel(key.split(' vs. ')[1] + ' Mean Tags')
    
    #set max and min
    countmax = np.max([np.max(de.g0_mean), np.max(de.g1_mean)])
    axs[1].set_xlim([0,np.ceil(countmax)])
    axs[1].set_ylim([0,np.ceil(countmax)])
                      
    plt.savefig('./figures/'+key+'_MAPlot_scatter.png', bbox_inches='tight')
    plt.close()
    
    fig, ax = plt.subplots(figsize=(4,4))
    
        # plot group by group scatter:
    ax.scatter(
        x=de.g0_mean,
        y=de.g1_mean,
        s=dot_sizes, #de.log10p+0.05,
        c=dot_colors)
    
    ax.set_xlabel(key.split(' vs. ')[0] + ' Mean Tags')
    ax.set_ylabel(key.split(' vs. ')[1] + ' Mean Tags')
    
    #set max and min
    countmax = np.max([np.max(de.g0_mean), np.max(de.g1_mean)])
    ax.set_xlim([0,np.ceil(countmax)])
    ax.set_ylim([0,np.ceil(countmax)])
    
    ax.text(0.5,12.5,
        s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc > 1)), key.split(' vs. ')[1]),
        fontsize=14,
        c=color[1])
    ax.text(12.5,0.5,
        s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc < -1)), key.split(' vs. ')[0]),
        fontsize=14,
        c=color[0],
        rotation=-90)
    
    plt.savefig('./figures/'+key+'_scatter.png', bbox_inches='tight')
    plt.close()
# Out:
# 00_c57 vs. 01_balbc
# N genes downregulated 196
# N genes upregulated 240
#
# 00_c57 vs. 02_aj
# N genes downregulated 696
# N genes upregulated 355
#
# 01_balbc vs. 02_aj
# N genes downregulated 170
# N genes upregulated 78

# %% [markdown]
# # Cluster differential enhancers:
# ____
# ### All enhancers

# %%
pval = 0.05
fc = 2

# grab differential enhancers for each comparison
sig_peaks_id = []
for comp in comps:
    de = comp_dict[comp]
    sig_peaks_id.extend(de.loc[((de.adj_pval <= pval) & (np.abs(de.log2fc) >= fc)), :].index.tolist())

sig_peaks_id = np.unique(sig_peaks_id)
print(len(sig_peaks_id))
sig_peaks = peak_mat.reindex(sig_peaks_id)
sig_peaks.columns = sig_peaks.columns.str.split('/').str[-1].str.split(' Tag Count').str[0]

sns.clustermap(np.log2(sig_peaks+1),
               z_score=0,
               cmap='RdBu_r',
               col_colors=['#4daf4a', '#4daf4a',
                           '#377eb8', '#377eb8',
                           '#e41a1c', '#e41a1c'])
plt.savefig('./figures/diff_peaks_clustermap.png', bbox_inches='tight')
# Out:
# 1172

# %% [markdown]
# ### distal enhancers only

# %%
pval = 0.05
fc = 1

# grab differential enhancers for each comparison
sig_peaks_id = []
for comp in comps:
    de = comp_dict[comp]
    sig_peaks_bool = (((de.adj_pval <= pval) & (np.abs(de.log2fc) >= fc)) & (np.abs(de.TSS_dist) >= 3000))
    sig_peaks_id.extend(de.loc[sig_peaks_bool, :].index.tolist())

sig_peaks_id = np.unique(sig_peaks_id)
print(len(sig_peaks_id))
sig_peaks = peak_mat.reindex(sig_peaks_id)
sig_peaks.columns = sig_peaks.columns.str.split('/').str[-1].str.split(' Tag Count').str[0]

sns.clustermap(np.log2(sig_peaks+1),
               z_score=0,
               cmap='RdBu_r',
               col_colors=['#4daf4a', '#4daf4a',
                           '#377eb8', '#377eb8',
                           '#e41a1c', '#e41a1c'])
plt.savefig('./figures/diff_peaks_distal_clustermap.png', bbox_inches='tight')
# Out:
# 1105

# %% [markdown]
# # Save differential peaks for analysis in GREAT

# %%
if not os.path.isdir('./great_analysis/'):
    os.mkdir('./great_analysis/')
    
if not os.path.isdir('./great_analysis/peak_files/'):
    os.mkdir('./great_analysis/peak_files/')
    
if not os.path.isdir('./great_analysis/bed_files/'):
    os.mkdir('./great_analysis/bed_files/')

# %%
# initialize dict and list of cell types
peak_lists = {}
bg_lists = {}
cells = ['00_c57',
         '01_balbc',
         '02_aj']

# set pvalue and fc thresholds
fc = np.log2(2)
pval = 0.05

for cell in cells:
    print('Analyzing', cell, '...\n')
    
    # set count
    count = 0
    
    for key in comp_dict.keys():
        
        # select get diff data frame.
        df = comp_dict[key]
        
        # check on counter
        print(count)


        # initialize lists if count == 0
        if count == 0:
            # fold change direction depends on the location of the cell in the comparison.
            # if cell is in first position it is reference - so negative log2fc is higher in first position
            if cell in key.split(' vs. ')[0]:
                u = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                i = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                count = count + 1
            # if cell is in second position it is comparison - so positive log2fc is higher in second position
            elif cell in key.split(' vs. ')[1]:
                u = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                i = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                count = count + 1

        else:
            # fold change direction depends on the location of the cell in the comparison.
            # if cell is in first position it is reference - so negative log2fc is higher in first position
            if cell in key.split(' vs. ')[0]:
                u = u.union(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                i = i.intersection(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                count = count + 1
            # if cell is in second position it is comparison - so positive log2fc is higher in second position
            elif cell in key.split(' vs. ')[1]:
                u = u.union(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                i = i.intersection(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                count = count + 1

        
        # summarize iteration
        print('For comp:', key)
        print('Union set at:', len(u), 'peaks')
        print('Intersection set at:', len(i), 'peaks\n')
     
    
        # store lists
        peak_lists[cell+'_union'] = u
        peak_lists[cell+'_intersection'] = i
# Out:
# Analyzing 00_c57 ...
#
# 0
# For comp: 00_c57 vs. 01_balbc
# Union set at: 195 peaks
# Intersection set at: 195 peaks
#
# 1
# For comp: 00_c57 vs. 02_aj
# Union set at: 769 peaks
# Intersection set at: 118 peaks
#
# 2
# For comp: 01_balbc vs. 02_aj
# Union set at: 769 peaks
# Intersection set at: 118 peaks
#
# Analyzing 01_balbc ...
#
# 0
# For comp: 00_c57 vs. 01_balbc
# Union set at: 240 peaks
# Intersection set at: 240 peaks
#
# 1
# For comp: 00_c57 vs. 02_aj
# Union set at: 240 peaks
# Intersection set at: 240 peaks
#
# 1
# For comp: 01_balbc vs. 02_aj
# Union set at: 379 peaks
# Intersection set at: 26 peaks
#
# Analyzing 02_aj ...
#
# 0
# For comp: 00_c57 vs. 01_balbc
# Union set at: 379 peaks
# Intersection set at: 26 peaks
#
# 0
# For comp: 00_c57 vs. 02_aj
# Union set at: 353 peaks
# Intersection set at: 353 peaks
#
# 1
# For comp: 01_balbc vs. 02_aj
# Union set at: 402 peaks
# Intersection set at: 28 peaks

# %% [markdown]
# if np.NaN get introduced into the matrix then it converts 'int' type columns to 'float' type columns, this is not ideal and interferes with downstream peak analysis so we create a dict to change the start and end columns back to integers just in case

# %%
convert_dict = {'Start': int,
                'End': int}

for key in peak_lists.keys():
    # save cell specific promoters
    tmp = diff_peak.reindex(peak_lists[key]).dropna(how='all').iloc[:, :4]
    tmp = tmp.astype(convert_dict)
    tmp.to_csv('./great_analysis/peak_files/'+key+'_poised_peaks.txt',
               sep='\t')

# %% [markdown]
# Save full set of peaks for background

# %%
diff_peak.iloc[:, :4].to_csv(
    './great_analysis/peak_files/all_peaks.txt',
    sep='\t')

# %% [markdown]
# Convert peaks to bed file

# %%
# %%bash
# # delete the existing script file
# rm ./peak_to_bed_great.sh
# # create a script file
# touch ./peak_to_bed_great.sh
# Out:
# rm: cannot remove ‘./peak_to_bed_great.sh’: No such file or directory

# %%
# %%bash
# for peakfile in ./great_analysis/peak_files/*txt;
# do bedfile=${i/act/bg};
# out=${peakfile/.txt/.bed};
# out=${out/peak_files/bed_files}
# echo "pos2bed.pl -o $out $peakfile" >> ./peak_to_bed_great.sh
# done

# %% [markdown]
# # Create bed files for visualization in browser

# %%
if not os.path.isdir('./bed_files/'):
    os.mkdir('./bed_files/')

# %%
# !cp ./great_analysis/bed_files/* ./bed_files/

# %%
# !ls ./bed_files/
# Out:
# 00_c57_intersection_poised_peaks.bed	02_aj_intersection_poised_peaks.bed
# 00_c57_union_poised_peaks.bed		02_aj_union_poised_peaks.bed
# 01_balbc_intersection_poised_peaks.bed	all_peaks.bed
# 01_balbc_union_poised_peaks.bed

# %%
with open('./label_bed.sh', 'w') as f:
    for i in glob.glob('./bed_files/*poised_peaks.bed'):
       
        strain = i.split('/')[-1].split('_')[1]
        settype = i.split('/')[-1].split('_')[2]
        group = "control_30weeks"
        chip = 'ATAC'

        # set track names for upload to ucsc genome browser
        lab = "'track name=\"%s_%s_%s_%s\" description=\"%s %s %s %s DESeq2\"'" % (strain, chip, group, settype, strain, group, chip, settype)
        lab_dist = "'track name=\"%s_%s_%s_%s_distal\" description=\"%s %s %s %s DESeq2\"'" % (strain, chip, group, settype, strain, group, chip, settype)

        # set labels - can't think of a more clever way to do this so we will just
        # use the simple if / else statement to switch labels depending on our 
        # peak set being distal or all
        
        if 'distal' in i:
            l = lab_dist
        else:
            l = lab
        
        label_track = ['echo', l, '|', 'cat', '-',
                       i,
                       '> temp && mv temp',
                       i, '\n']
    
        f.write(' '.join(label_track))
        
    f.close()

# %% [markdown]
# label all peaks post-hoc

# %%
# %%bash
#
# echo 'track name="kupffer_control_30weeks_atac_merged" description="Kupffer Control 30weeks ATAC All Strains"' \
# | cat - ./bed_files/all_peaks.bed \
# > temp && mv temp ./bed_files/all_peaks.bed

# %% [markdown]
# # Check differential peak quality in browser

# %%
# make location column for peak dict (for examining on browser)
diff_peak['location'] = diff_peak.Chr + ':' + diff_peak.Start.map(str) + '-' + diff_peak.End.map(str)

# %%
diff_peak.sort_values('00_c57 vs. 01_balbc adj. p-value', ascending=True).head(20)
# Out:
#                                                       Chr      Start  \
# PeakID
# Merged-chr11-3174079-3                              chr11    3173975
# Merged-chr11-3157961-2                              chr11    3157860
# Merged-chr11-3174396-2                              chr11    3174286
# Merged-chr8-20424848-3                               chr8   20424749
# Merged-chr8-127441381-1                              chr8  127441281
# Merged-chr11-3157631-2                              chr11    3157531
# Merged-chr11-3157004-2                              chr11    3156909
# Merged-chr4-95557439-3                               chr4   95557338
# Merged-chr8-19784657-3                               chr8   19784558
# Merged-chr11-3127518-1                              chr11    3127418
# Merged-chr11-3151551-2                              chr11    3151452
# Merged-chr6-92941528-1                               chr6   92941428
# Merged-chr4-119177948-2                              chr4  119177835
# Merged-chr1-173961691-2                              chr1  173961597
# Merged-chr8-34744898-2                               chr8   34744799
# Merged-chr3-127355435-3                              chr3  127355341
# Merged-chr6-5339513-1                                chr6    5339413
# Merged-chr11-3161352-2                              chr11    3161223
# Merged-chr4_GL456216_random-17332-1  chr4_GL456216_random      17232
# Merged-chr14-30577821-1                             chr14   30577721
#
#                                            End Strand   Peak Score  \
# PeakID
# Merged-chr11-3174079-3                 3174175      +   893.666687
# Merged-chr11-3157961-2                 3158060      +  1000.000000
# Merged-chr11-3174396-2                 3174486      +  1000.000000
# Merged-chr8-20424848-3                20424949      +  1000.000000
# Merged-chr8-127441381-1              127441481      +  1000.000000
# Merged-chr11-3157631-2                 3157731      +  1000.000000
# Merged-chr11-3157004-2                 3157109      +  1000.000000
# Merged-chr4-95557439-3                95557538      +   929.000000
# Merged-chr8-19784657-3                19784758      +  1000.000000
# Merged-chr11-3127518-1                 3127618      +  1000.000000
# Merged-chr11-3151551-2                 3151652      +   859.500000
# Merged-chr6-92941528-1                92941628      +  1000.000000
# Merged-chr4-119177948-2              119178035      +  1000.000000
# Merged-chr1-173961691-2              173961797      +  1000.000000
# Merged-chr8-34744898-2                34744999      +   813.000000
# Merged-chr3-127355435-3              127355541      +  1000.000000
# Merged-chr6-5339513-1                  5339613      +  1000.000000
# Merged-chr11-3161352-2                 3161423      +  1000.000000
# Merged-chr4_GL456216_random-17332-1      17432      +  1000.000000
# Merged-chr14-30577821-1               30577921      +  1000.000000
#
#                                                                Focus Ratio/Region Size  \
# PeakID
# Merged-chr11-3174079-3               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr11-3157961-2               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr11-3174396-2               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr8-20424848-3               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr8-127441381-1              ./atac_peak_files/c57bl6j_kupffer_control_30we...
# Merged-chr11-3157631-2               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr11-3157004-2               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr4-95557439-3               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr8-19784657-3               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr11-3127518-1                ./atac_peak_files/aj_kupffer_control_30weeks.idr
# Merged-chr11-3151551-2               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr6-92941528-1               ./atac_peak_files/balbcj_kupffer_control_30wee...
# Merged-chr4-119177948-2              ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr1-173961691-2              ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr8-34744898-2               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr3-127355435-3              ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr6-5339513-1                ./atac_peak_files/c57bl6j_kupffer_control_30we...
# Merged-chr11-3161352-2               ./atac_peak_files/aj_kupffer_control_30weeks.i...
# Merged-chr4_GL456216_random-17332-1  ./atac_peak_files/c57bl6j_kupffer_control_30we...
# Merged-chr14-30577821-1              ./atac_peak_files/c57bl6j_kupffer_control_30we...
#
#                                                                 Annotation  \
# PeakID
# Merged-chr11-3174079-3                  intron (NM_030207, intron 6 of 32)
# Merged-chr11-3157961-2                 intron (NM_030207, intron 10 of 32)
# Merged-chr11-3174396-2                  intron (NM_030207, intron 6 of 32)
# Merged-chr8-20424848-3                            promoter-TSS (NR_028428)
# Merged-chr8-127441381-1                intron (NM_033620, intron 20 of 24)
# Merged-chr11-3157631-2                 intron (NM_030207, intron 11 of 32)
# Merged-chr11-3157004-2                 intron (NM_030207, intron 11 of 32)
# Merged-chr4-95557439-3                         promoter-TSS (NM_001113412)
# Merged-chr8-19784657-3                intron (NM_001270553, intron 6 of 9)
# Merged-chr11-3127518-1                 non-coding (NR_003517, exon 3 of 7)
# Merged-chr11-3151551-2                 intron (NM_030207, intron 14 of 32)
# Merged-chr6-92941528-1                   intron (NR_015530, intron 1 of 2)
# Merged-chr4-119177948-2                  3' UTR (NM_013848, exon 13 of 13)
# Merged-chr1-173961691-2                                    TTS (NM_011940)
# Merged-chr8-34744898-2                                          Intergenic
# Merged-chr3-127355435-3              intron (NM_001327939, intron 1 of 45)
# Merged-chr6-5339513-1                                           Intergenic
# Merged-chr11-3161352-2                  intron (NM_030207, intron 9 of 32)
# Merged-chr4_GL456216_random-17332-1   intron (NM_001033326, intron 1 of 6)
# Merged-chr14-30577821-1                                         Intergenic
#
#                                                        Detailed Annotation  \
# PeakID
# Merged-chr11-3174079-3                  intron (NM_030207, intron 6 of 32)
# Merged-chr11-3157961-2                 intron (NM_030207, intron 10 of 32)
# Merged-chr11-3174396-2                                     PB1D11|SINE|Alu
# Merged-chr8-20424848-3                            promoter-TSS (NR_028428)
# Merged-chr8-127441381-1                intron (NM_033620, intron 20 of 24)
# Merged-chr11-3157631-2                 intron (NM_030207, intron 11 of 32)
# Merged-chr11-3157004-2                 intron (NM_030207, intron 11 of 32)
# Merged-chr4-95557439-3                         promoter-TSS (NM_001113412)
# Merged-chr8-19784657-3                                                 CpG
# Merged-chr11-3127518-1                 non-coding (NR_003517, exon 3 of 7)
# Merged-chr11-3151551-2                 intron (NM_030207, intron 14 of 32)
# Merged-chr6-92941528-1                   intron (NR_015530, intron 1 of 2)
# Merged-chr4-119177948-2                  3' UTR (NM_013848, exon 13 of 13)
# Merged-chr1-173961691-2                                    TTS (NM_011940)
# Merged-chr8-34744898-2                                          Intergenic
# Merged-chr3-127355435-3              intron (NM_001327939, intron 1 of 45)
# Merged-chr6-5339513-1                                      Lx3_Mus|LINE|L1
# Merged-chr11-3161352-2                  intron (NM_030207, intron 9 of 32)
# Merged-chr4_GL456216_random-17332-1   intron (NM_001033326, intron 1 of 6)
# Merged-chr14-30577821-1                                         Intergenic
#
#                                      Distance to TSS Nearest PromoterID  ...  \
# PeakID                                                                   ...
# Merged-chr11-3174079-3                       19388.0          NM_030207  ...
# Merged-chr11-3157961-2                       33939.0          NR_003517  ...
# Merged-chr11-3174396-2                       19077.0          NM_030207  ...
# Merged-chr8-20424848-3                         -35.0          NR_028428  ...
# Merged-chr8-127441381-1                     141729.0       NM_001013580  ...
# Merged-chr11-3157631-2                       33610.0          NR_003517  ...
# Merged-chr11-3157004-2                       32988.0          NR_003517  ...
# Merged-chr4-95557439-3                         -69.0       NM_001113412  ...
# Merged-chr8-19784657-3                       55082.0       NM_001039553  ...
# Merged-chr11-3127518-1                        3497.0          NR_003517  ...
# Merged-chr11-3151551-2                       27531.0          NR_003517  ...
# Merged-chr6-92941528-1                         946.0          NR_015530  ...
# Merged-chr4-119177948-2                      -3740.0       NM_001145936  ...
# Merged-chr1-173961691-2                     -19025.0       NM_001302650  ...
# Merged-chr8-34744898-2                      -62711.0          NM_176933  ...
# Merged-chr3-127355435-3                      53617.0       NM_001327939  ...
# Merged-chr6-5339513-1                       -41140.0          NM_183308  ...
# Merged-chr11-3161352-2                       32140.0          NM_030207  ...
# Merged-chr4_GL456216_random-17332-1           1451.0       NM_001033326  ...
# Merged-chr14-30577821-1                       5672.0          NR_037237  ...
#
#                                      00_c57 vs. 01_balbc Log2 Fold Change  \
# PeakID
# Merged-chr11-3174079-3                                           3.746851
# Merged-chr11-3157961-2                                           7.011840
# Merged-chr11-3174396-2                                          12.276263
# Merged-chr8-20424848-3                                           3.023440
# Merged-chr8-127441381-1                                         -3.397529
# Merged-chr11-3157631-2                                          10.666477
# Merged-chr11-3157004-2                                           9.171004
# Merged-chr4-95557439-3                                          -2.838406
# Merged-chr8-19784657-3                                           1.747248
# Merged-chr11-3127518-1                                           4.238611
# Merged-chr11-3151551-2                                           4.826427
# Merged-chr6-92941528-1                                           5.531833
# Merged-chr4-119177948-2                                         -5.322614
# Merged-chr1-173961691-2                                          3.203713
# Merged-chr8-34744898-2                                          -3.914865
# Merged-chr3-127355435-3                                         -2.363540
# Merged-chr6-5339513-1                                           -4.238673
# Merged-chr11-3161352-2                                           9.211768
# Merged-chr4_GL456216_random-17332-1                             -8.988162
# Merged-chr14-30577821-1                                         -5.619307
#
#                                     00_c57 vs. 01_balbc p-value  \
# PeakID
# Merged-chr11-3174079-3                             1.838753e-28
# Merged-chr11-3157961-2                             1.143767e-22
# Merged-chr11-3174396-2                             2.952853e-17
# Merged-chr8-20424848-3                             5.507299e-17
# Merged-chr8-127441381-1                            1.246956e-13
# Merged-chr11-3157631-2                             3.740217e-13
# Merged-chr11-3157004-2                             7.741896e-13
# Merged-chr4-95557439-3                             6.710374e-12
# Merged-chr8-19784657-3                             3.552918e-11
# Merged-chr11-3127518-1                             5.307632e-11
# Merged-chr11-3151551-2                             1.009980e-10
# Merged-chr6-92941528-1                             1.445090e-10
# Merged-chr4-119177948-2                            1.510796e-10
# Merged-chr1-173961691-2                            2.591188e-10
# Merged-chr8-34744898-2                             3.537737e-10
# Merged-chr3-127355435-3                            3.622462e-10
# Merged-chr6-5339513-1                              3.567437e-10
# Merged-chr11-3161352-2                             1.235546e-09
# Merged-chr4_GL456216_random-17332-1                1.639346e-09
# Merged-chr14-30577821-1                            1.926091e-09
#
#                                     00_c57 vs. 01_balbc adj. p-value  \
# PeakID
# Merged-chr11-3174079-3                                  1.002874e-23
# Merged-chr11-3157961-2                                  3.119109e-18
# Merged-chr11-3174396-2                                  5.368385e-13
# Merged-chr8-20424848-3                                  7.509340e-13
# Merged-chr8-127441381-1                                 1.360205e-09
# Merged-chr11-3157631-2                                  3.399920e-09
# Merged-chr11-3157004-2                                  6.032154e-09
# Merged-chr4-95557439-3                                  4.574881e-08
# Merged-chr8-19784657-3                                  2.153108e-07
# Merged-chr11-3127518-1                                  2.894835e-07
# Merged-chr11-3151551-2                                  5.007756e-07
# Merged-chr6-92941528-1                                  6.338487e-07
# Merged-chr4-119177948-2                                 6.338487e-07
# Merged-chr1-173961691-2                                 1.009471e-06
# Merged-chr8-34744898-2                                  1.162192e-06
# Merged-chr3-127355435-3                                 1.162192e-06
# Merged-chr6-5339513-1                                   1.162192e-06
# Merged-chr11-3161352-2                                  3.743772e-06
# Merged-chr4_GL456216_random-17332-1                     4.705872e-06
# Merged-chr14-30577821-1                                 5.252546e-06
#
#                                     00_c57 vs. 02_aj Log2 Fold Change  \
# PeakID
# Merged-chr11-3174079-3                                       2.660706
# Merged-chr11-3157961-2                                       6.047333
# Merged-chr11-3174396-2                                      11.366144
# Merged-chr8-20424848-3                                       1.799932
# Merged-chr8-127441381-1                                     -5.185075
# Merged-chr11-3157631-2                                       9.807787
# Merged-chr11-3157004-2                                       8.533007
# Merged-chr4-95557439-3                                      -2.981266
# Merged-chr8-19784657-3                                       1.054579
# Merged-chr11-3127518-1                                       3.188035
# Merged-chr11-3151551-2                                       3.319347
# Merged-chr6-92941528-1                                       2.300309
# Merged-chr4-119177948-2                                     -0.390623
# Merged-chr1-173961691-2                                      2.036211
# Merged-chr8-34744898-2                                      -3.330847
# Merged-chr3-127355435-3                                     -1.450524
# Merged-chr6-5339513-1                                       -5.594541
# Merged-chr11-3161352-2                                       7.588658
# Merged-chr4_GL456216_random-17332-1                         -9.924341
# Merged-chr14-30577821-1                                     -6.152362
#
#                                     00_c57 vs. 02_aj p-value  \
# PeakID
# Merged-chr11-3174079-3                          8.830647e-15
# Merged-chr11-3157961-2                          1.109487e-17
# Merged-chr11-3174396-2                          6.708393e-15
# Merged-chr8-20424848-3                          4.023810e-06
# Merged-chr8-127441381-1                         2.448425e-25
# Merged-chr11-3157631-2                          2.421079e-11
# Merged-chr11-3157004-2                          2.575693e-11
# Merged-chr4-95557439-3                          1.319794e-20
# Merged-chr8-19784657-3                          1.738318e-05
# Merged-chr11-3127518-1                          4.693364e-03
# Merged-chr11-3151551-2                          1.157660e-04
# Merged-chr6-92941528-1                          5.746929e-02
# Merged-chr4-119177948-2                         1.648159e-01
# Merged-chr1-173961691-2                         1.689367e-04
# Merged-chr8-34744898-2                          3.880353e-15
# Merged-chr3-127355435-3                         2.608290e-09
# Merged-chr6-5339513-1                           4.500132e-16
# Merged-chr11-3161352-2                          1.300955e-06
# Merged-chr4_GL456216_random-17332-1             1.614362e-11
# Merged-chr14-30577821-1                         2.621486e-04
#
#                                     00_c57 vs. 02_aj adj. p-value  \
# PeakID
# Merged-chr11-3174079-3                               5.352059e-11
# Merged-chr11-3157961-2                               2.017307e-13
# Merged-chr11-3174396-2                               4.574034e-11
# Merged-chr8-20424848-3                               8.607325e-04
# Merged-chr8-127441381-1                              1.335543e-20
# Merged-chr11-3157631-2                               6.002845e-08
# Merged-chr11-3157004-2                               6.108537e-08
# Merged-chr4-95557439-3                               3.599540e-16
# Merged-chr8-19784657-3                               2.528534e-03
# Merged-chr11-3127518-1                               1.539883e-01
# Merged-chr11-3151551-2                               1.030129e-02
# Merged-chr6-92941528-1                               6.379279e-01
# Merged-chr4-119177948-2                              8.724126e-01
# Merged-chr1-173961691-2                              1.383632e-02
# Merged-chr8-34744898-2                               3.023737e-11
# Merged-chr3-127355435-3                              2.845488e-06
# Merged-chr6-5339513-1                                4.909374e-12
# Merged-chr11-3161352-2                               3.657896e-04
# Merged-chr4_GL456216_random-17332-1                  4.892143e-08
# Merged-chr14-30577821-1                              1.940220e-02
#
#                                     01_balbc vs. 02_aj Log2 Fold Change  \
# PeakID
# Merged-chr11-3174079-3                                        -1.080665
# Merged-chr11-3157961-2                                        -0.958692
# Merged-chr11-3174396-2                                        -0.903467
# Merged-chr8-20424848-3                                        -1.222822
# Merged-chr8-127441381-1                                       -1.660910
# Merged-chr11-3157631-2                                        -0.848407
# Merged-chr11-3157004-2                                        -0.638325
# Merged-chr4-95557439-3                                        -0.173721
# Merged-chr8-19784657-3                                        -0.691238
# Merged-chr11-3127518-1                                        -1.051642
# Merged-chr11-3151551-2                                        -1.490887
# Merged-chr6-92941528-1                                        -3.145612
# Merged-chr4-119177948-2                                        4.915035
# Merged-chr1-173961691-2                                       -1.190139
# Merged-chr8-34744898-2                                         0.670679
# Merged-chr3-127355435-3                                        0.928068
# Merged-chr6-5339513-1                                         -1.338111
# Merged-chr11-3161352-2                                        -1.624350
# Merged-chr4_GL456216_random-17332-1                                 NaN
# Merged-chr14-30577821-1                                       -0.459806
#
#                                     01_balbc vs. 02_aj p-value  \
# PeakID
# Merged-chr11-3174079-3                            6.572829e-07
# Merged-chr11-3157961-2                            9.306346e-05
# Merged-chr11-3174396-2                            2.878211e-09
# Merged-chr8-20424848-3                            1.113619e-06
# Merged-chr8-127441381-1                           8.357882e-02
# Merged-chr11-3157631-2                            1.669424e-04
# Merged-chr11-3157004-2                            6.199734e-03
# Merged-chr4-95557439-3                            7.799295e-01
# Merged-chr8-19784657-3                            8.393520e-04
# Merged-chr11-3127518-1                            3.300350e-01
# Merged-chr11-3151551-2                            9.489279e-02
# Merged-chr6-92941528-1                            3.261055e-10
# Merged-chr4-119177948-2                           2.475522e-09
# Merged-chr1-173961691-2                           3.889047e-04
# Merged-chr8-34744898-2                            5.107323e-01
# Merged-chr3-127355435-3                           3.687993e-02
# Merged-chr6-5339513-1                             4.064214e-01
# Merged-chr11-3161352-2                            4.257893e-02
# Merged-chr4_GL456216_random-17332-1               1.000000e+00
# Merged-chr14-30577821-1                           8.378828e-01
#
#                                      01_balbc vs. 02_aj adj. p-value  \
# PeakID
# Merged-chr11-3174079-3                                      0.000703
# Merged-chr11-3157961-2                                      0.027184
# Merged-chr11-3174396-2                                      0.000010
# Merged-chr8-20424848-3                                      0.000992
# Merged-chr8-127441381-1                                     0.999889
# Merged-chr11-3157631-2                                      0.040574
# Merged-chr11-3157004-2                                      0.383122
# Merged-chr4-95557439-3                                      0.999889
# Merged-chr8-19784657-3                                      0.115339
# Merged-chr11-3127518-1                                      0.999889
# Merged-chr11-3151551-2                                      0.999889
# Merged-chr6-92941528-1                                      0.000002
# Merged-chr4-119177948-2                                     0.000009
# Merged-chr1-173961691-2                                     0.072942
# Merged-chr8-34744898-2                                      0.999889
# Merged-chr3-127355435-3                                     0.886337
# Merged-chr6-5339513-1                                       1.000000
# Merged-chr11-3161352-2                                      0.928399
# Merged-chr4_GL456216_random-17332-1                         1.000000
# Merged-chr14-30577821-1                                     1.000000
#
#                                                              location
# PeakID
# Merged-chr11-3174079-3                          chr11:3173975-3174175
# Merged-chr11-3157961-2                          chr11:3157860-3158060
# Merged-chr11-3174396-2                          chr11:3174286-3174486
# Merged-chr8-20424848-3                         chr8:20424749-20424949
# Merged-chr8-127441381-1                      chr8:127441281-127441481
# Merged-chr11-3157631-2                          chr11:3157531-3157731
# Merged-chr11-3157004-2                          chr11:3156909-3157109
# Merged-chr4-95557439-3                         chr4:95557338-95557538
# Merged-chr8-19784657-3                         chr8:19784558-19784758
# Merged-chr11-3127518-1                          chr11:3127418-3127618
# Merged-chr11-3151551-2                          chr11:3151452-3151652
# Merged-chr6-92941528-1                         chr6:92941428-92941628
# Merged-chr4-119177948-2                      chr4:119177835-119178035
# Merged-chr1-173961691-2                      chr1:173961597-173961797
# Merged-chr8-34744898-2                         chr8:34744799-34744999
# Merged-chr3-127355435-3                      chr3:127355341-127355541
# Merged-chr6-5339513-1                            chr6:5339413-5339613
# Merged-chr11-3161352-2                          chr11:3161223-3161423
# Merged-chr4_GL456216_random-17332-1  chr4_GL456216_random:17232-17432
# Merged-chr14-30577821-1                       chr14:30577721-30577921
#
# [20 rows x 34 columns]

# %% [markdown]
# ### Balb specific enhancer example

# %% [markdown]
# ![image.png](attachment:image.png)

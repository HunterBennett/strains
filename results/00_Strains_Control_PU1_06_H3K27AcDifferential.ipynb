# %% [markdown]
# Hunter Bennett | Glass Lab | Kupffer Strains Project | February 03 2021
# This is a re-vamp of the differential peak calling pipeline for comparisons within strains in a given condition (healthy, CCl4, NASH). This pipeline takes in ATAC-seq peaks annotated with H3K27Ac ChIP-seq data (or other histone modified data) from three strains (c57, balb, and aj) and compares each strain to the other pairwise. The main outputs of this file are:
# 1. A homer differential peak file containing each pairwise comparison.
# 2. Scatterplots of each pairwise comparison with significant peaks highlighted.
# 3. Heatmaps of differential peaks across all comparisons to highlight patterns.
# 4. Peak files for GREAT analysis of functional annotations associated with genomic regions.

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('white')

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from plotting_scripts import label_point, pca_rpkm_mat, get_diff_volcano
from homer_preprocessing import read_annotated_peaks, import_homer_diffpeak, pull_comparisons_get_diff

# %%
dataDirectory = ''
workingDirectory = '/home/h1bennet/strains/results/00_Strains_Control_PU1/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# ### Read in raw gene expression files

# %%
df, mat = read_annotated_peaks('./merged_peaks/ann_raw_h3k27ac_control_pu1_peaks_all.txt')

# %%
best_reps = [
    '00_C57_Kupffer_H3K27Ac_control_young_C571A_170915',
    '00_C57_Kupffer_H3K27Ac_control_young_C572A_180423',
    '01_balbc_Kupffer_H3K27Ac_control_young_Balb10ABC_170915',
    '01_balbc_Kupffer_H3K27Ac_control_young_Balb11AB_170915']

# %%
# import annotation file
df, mat = read_annotated_peaks('./merged_peaks/ann_raw_h3k27ac_control_pu1_peaks_all.txt')

# pull out selected samples
tst = np.append(np.asarray([True]*18, 'bool'), mat.columns.str.contains('|'.join(best_reps)))
df= df.loc[:, tst]

df.to_csv('./merged_peaks/ann_raw_h3k27ac_control_pu1_peaks_filtered.txt', sep='\t')

# %%
# %%bash
# source activate deseq_36
# getDiffExpression.pl ./merged_peaks/ann_raw_h3k27ac_control_pu1_peaks_filtered.txt \
# 00_c57 00_c57 \
# 01_balbc 01_balbc \
# -peaks > ./merged_peaks/diff_output_h3k27ac.txt
# Out:
# 	Treating input as file generated by annotatePeaks.pl (-peaks)
#
# 	Performing variance stabalization (rlog)...
#
#
# 	Warning: getDiffExpression.pl now defaults to DESeq2 for calculations (instead of edgeR)
#
# 	Using DESeq2 to calculate differential expression/enrichment...
# 	Output Stats 00_c57 vs. 01_balbc:
# 		Total Genes: 50443
# 		Total Up-regulated in 01_balbc vs. 00_c57: 1051 (2.084%) [log2fold>1, FDR<0.05]
# 		Total Dn-regulated in 01_balbc vs. 00_c57: 1472 (2.918%) [log2fold<-1, FDR<0.05]

# %% [markdown]
# ### Import differential peaks

# %%
diff_peak, peaks, peak_mat, peak_mat_quant = import_homer_diffpeak(
    './merged_peaks/diff_output_h3k27ac.txt',
    './merged_peaks/ann_raw_h3k27ac_control_pu1_peaks_all.txt')
# Out:
# annotatePeaks all peaks (51430, 22)
# getDiffExpression selected transcripts (50443, 25)
# annotatePeaks selected peaks (50443, 22)

# %%
comp_dict = pull_comparisons_get_diff(diff_peak, seq_type='Peak')

# %%
comps = ['00_c57 vs. 01_balbc']

groups = [[[0,1],[2,3]]]

cols = []
for i in groups:
    subcols = []
    for j in i:
        subcols.extend([k for k in j])
    cols.append(subcols)

colors = [['#4daf4a', '#377eb8']]

# %%
for key, col, group, color in zip(comps, cols, groups, colors):
#     print(key)
#     print('mean calculated using tag dirs:')
#     for colid in peak_mat.iloc[:, col].columns.tolist():
#         print(colid)
#     print('')
    de = comp_dict[key]
    de['logtpm'] = np.log2(peak_mat.iloc[:, col].mean(1)+1)
    de['log10p'] = -np.log10(de.adj_pval + 10**(-50))
    de['g0_mean'] = np.log2(peak_mat.iloc[:, group[0]].mean(1)+1)
    de['g1_mean'] = np.log2(peak_mat.iloc[:, group[1]].mean(1)+1)
    dot_colors = []
    dot_sizes = []
    for index, row in de.iterrows():
        if (row.adj_pval <= 0.05) & (-row.log2fc < 0):
            dot_colors.append(color[1])
            dot_sizes.append(row.log10p)
        elif (row.adj_pval <= 0.05) & (-row.log2fc > 0):
            dot_colors.append(color[0])
            dot_sizes.append(row.log10p)
        else:
            dot_colors.append('grey')
            dot_sizes.append(0.5)
    print(key)
    print('N peaks down', np.sum((de.adj_pval <= 0.05) & (de.log2fc < -1)))
    print('N peaks up', np.sum((de.adj_pval <= 0.05) & (de.log2fc > 1)))
    print('')
    fig, axs = plt.subplots(1, 2, figsize=(10,6))
    plt.subplots_adjust(wspace=0.5)

    axs[0].set_xlim(left=-np.ceil(np.max(np.abs(de.log2fc))),
                right=np.ceil(np.max(np.abs(de.log2fc))))
    axs[0].scatter(
        x=de.log2fc,
        y=de.logtpm,
        s=dot_sizes, #de.log10p+0.05,
        c=dot_colors)

    axs[0].set_ylabel('Mean Log2(TPM)')
    axs[0].set_xlabel('Log2FC')

    # plot group by group scatter:
    axs[1].scatter(
        x=de.g0_mean,
        y=de.g1_mean,
        s=dot_sizes, #de.log10p+0.05,
        c=dot_colors)
    
    axs[1].set_xlabel(key.split(' vs. ')[0] + ' Mean Tags')
    axs[1].set_ylabel(key.split(' vs. ')[1] + ' Mean Tags')
    
    #set max and min
    countmax = np.max([np.max(de.g0_mean), np.max(de.g1_mean)])
    axs[1].set_xlim([0,np.ceil(countmax)])
    axs[1].set_ylim([0,np.ceil(countmax)])
                      
    plt.savefig('./figures/'+key+'_MAPlot_scatter.png', bbox_inches='tight')
    plt.close()
    
    fig, ax = plt.subplots(figsize=(4,4))
    
        # plot group by group scatter:
    ax.scatter(
        x=de.g0_mean,
        y=de.g1_mean,
        s=dot_sizes, #de.log10p+0.05,
        c=dot_colors)
    
    ax.set_xlabel(key.split(' vs. ')[0] + ' Mean Tags')
    ax.set_ylabel(key.split(' vs. ')[1] + ' Mean Tags')
    
    #set max and min
    countmax = np.max([np.max(de.g0_mean), np.max(de.g1_mean)])
    ax.set_xlim([0,np.ceil(countmax)])
    ax.set_ylim([0,np.ceil(countmax)])
    
    ax.text(0.5,14.5,
        s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc > 1)), key.split(' vs. ')[1]),
        fontsize=14,
        c=color[1])
    ax.text(14.5,0.5,
        s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc < -1)), key.split(' vs. ')[0]),
        fontsize=14,
        c=color[0],
        rotation=-90)
    
    plt.savefig('./figures/'+key+'_scatter.png', bbox_inches='tight')
    # plt.close()
# Out:
# 00_c57 vs. 01_balbc
# N peaks down 1472
# N peaks up 1051

# %% [markdown]
# # Cluster differential enhancers:

# %% [markdown]
# ### all enhancers

# %%
pval = 0.05
fc = 2

# grab differential enhancers for each comparison
sig_peaks_id = []
for comp in comps:
    de = comp_dict[comp]
    sig_peaks_id.extend(de.loc[((de.adj_pval <= pval) & (np.abs(de.log2fc) >= fc)), :].index.tolist())

sig_peaks_id = np.unique(sig_peaks_id)
print(len(sig_peaks_id))
sig_peaks = peak_mat.reindex(sig_peaks_id)
sig_peaks.columns = sig_peaks.columns.str.split('/').str[-1].str.split(' Tag Count').str[0]

sns.clustermap(np.log2(sig_peaks+1),
               z_score=0,
               cmap='RdBu_r',
               col_colors=['#4daf4a', '#4daf4a',
                           '#377eb8', '#377eb8'])
plt.savefig('./figures/diff_peaks_clustermap.png', bbox_inches='tight')
# Out:
# 1144

# %% [markdown]
# ### distal enhancers only

# %%
pval = 0.05
fc = 1

# grab differential enhancers for each comparison
sig_peaks_id = []
for comp in comps:
    de = comp_dict[comp]
    sig_peaks_bool = (((de.adj_pval <= pval) & (np.abs(de.log2fc) >= fc)) & (np.abs(de.TSS_dist) >= 3000))
    sig_peaks_id.extend(de.loc[sig_peaks_bool, :].index.tolist())

sig_peaks_id = np.unique(sig_peaks_id)
print(len(sig_peaks_id))
sig_peaks = peak_mat.reindex(sig_peaks_id)
sig_peaks.columns = sig_peaks.columns.str.split('/').str[-1].str.split(' Tag Count').str[0]

sns.clustermap(np.log2(sig_peaks+1),
               z_score=0,
               cmap='RdBu_r',
               col_colors=['#4daf4a', '#4daf4a',
                           '#377eb8', '#377eb8'])
plt.savefig('./figures/diff_peaks_distal_clustermap.png', bbox_inches='tight')
# Out:
# 2069

# %% [markdown]
# # Save differential peaks for analysis in GREAT

# %%
if not os.path.isdir('./great_analysis/'):
    os.mkdir('./great_analysis/')
    
if not os.path.isdir('./great_analysis/peak_files/'):
    os.mkdir('./great_analysis/peak_files/')
    
if not os.path.isdir('./great_analysis/bed_files/'):
    os.mkdir('./great_analysis/bed_files/')

# %%
# initialize dict and list of cell types
peak_lists = {}
bg_lists = {}
cells = ['00_c57',
         '01_balbc']

# set pvalue and fc thresholds
fc = np.log2(2)
pval = 0.05

for cell in cells:
    print('Analyzing', cell, '...\n')
    
    # set count
    count = 0
    
    for key in comp_dict.keys():
        
        # select get diff data frame.
        df = comp_dict[key]
        
        # check on counter
        print(count)


        # initialize lists if count == 0
        if count == 0:
            # fold change direction depends on the location of the cell in the comparison.
            # if cell is in first position it is reference - so negative log2fc is higher in first position
            if cell in key.split(' vs. ')[0]:
                u = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                i = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                count = count + 1
            # if cell is in second position it is comparison - so positive log2fc is higher in second position
            elif cell in key.split(' vs. ')[1]:
                u = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                i = set(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                count = count + 1

        else:
            # fold change direction depends on the location of the cell in the comparison.
            # if cell is in first position it is reference - so negative log2fc is higher in first position
            if cell in key.split(' vs. ')[0]:
                u = u.union(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                i = i.intersection(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] < -fc)])
                count = count + 1
            # if cell is in second position it is comparison - so positive log2fc is higher in second position
            elif cell in key.split(' vs. ')[1]:
                u = u.union(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                i = i.intersection(df.index[(df.loc[:, 'adj_pval'] <= pval) & (df.loc[:, 'log2fc'] > fc)])
                count = count + 1

        
        # summarize iteration
        print('For comp:', key)
        print('Union set at:', len(u), 'peaks')
        print('Intersection set at:', len(i), 'peaks\n')
     
    
        # store lists
        peak_lists[cell+'_union'] = u
        peak_lists[cell+'_intersection'] = i
# Out:
# Analyzing 00_c57 ...
#
# 0
# For comp: 00_c57 vs. 01_balbc
# Union set at: 1472 peaks
# Intersection set at: 1472 peaks
#
# Analyzing 01_balbc ...
#
# 0
# For comp: 00_c57 vs. 01_balbc
# Union set at: 1051 peaks
# Intersection set at: 1051 peaks

# %% [markdown]
# ### For annotated peaks we want to pull the peak locations from the original merged ATAC-seq file

# %%
atac_peaks = pd.read_csv('./merged_peaks/idr_peaks_merged.txt', sep='\t', index_col=0)

# %%
new_start = []
new_end = []
for index, row in atac_peaks.iterrows():
    center = row.start + int(np.floor((row.end - row.start)/2))
    new_start.append(center - 100)
    new_end.append(center + 100)
    
atac_peaks_200bp = atac_peaks.iloc[:, :4].copy(deep=True)
atac_peaks_200bp['start'] = new_start
atac_peaks_200bp['end'] = new_end
atac_peaks_200bp.index.rename('PeakID', inplace=True)

# %% [markdown]
# if np.NaN get introduced into the matrix then it converts 'int' type columns to 'float' type columns, this is not ideal and interferes with downstream peak analysis so we create a dict to change the start and end columns back to integers just in case

# %%
convert_dict = {'start': int,
                'end': int}

# %%
for key in peak_lists.keys():
    # save cell specific promoters
    tmp = atac_peaks_200bp.reindex(peak_lists[key]).dropna(how='all').iloc[:, :4]
    tmp = tmp.astype(convert_dict)
    # filter unknown chromosomes
    tmp = tmp.loc[~tmp.chr.str.contains('random'), :]
    tmp.to_csv('./great_analysis/peak_files/'+key+'_h3k27ac_act_peaks.txt',
               sep='\t')

# %% [markdown]
# Save full set of peaks for background

# %%
atac_peaks_200bp.iloc[:, :4].to_csv(
    './great_analysis/peak_files/pu1_all_peaks.txt',
    sep='\t')

# %% [markdown]
# Convert peaks to bed file

# %%
# %%bash
# # delete the existing script file
# rm ./peak_to_bed_great.sh
# # create a script file
# touch ./peak_to_bed_great.sh

# %%
# %%bash
# for peakfile in ./great_analysis/peak_files/*txt;
# do bedfile=${i/act/bg};
# out=${peakfile/.txt/.bed};
# out=${out/peak_files/bed_files}
# echo "pos2bed.pl -o $out $peakfile" >> ./peak_to_bed_great.sh
# done

# %% [markdown]
# # Create bed files for visualization in browser

# %%
if not os.path.isdir('./bed_files/'):
    os.mkdir('./bed_files/')

# %%
# !cp ./great_analysis/bed_files/* ./bed_files/

# %%
# !ls ./bed_files/
# Out:
# 00_balbc_intersection_poised_peaks.bed
# 00_balbc_union_poised_peaks.bed
# 00_c57_intersection_act_peaks.bed
# 00_c57_intersection_h3k27ac_act_peaks.bed
# 00_c57_intersectionh3k27ac_act_peaks.bed
# 00_c57_union_act_peaks.bed
# 00_c57_union_h3k27ac_act_peaks.bed
# 00_c57_unionh3k27ac_act_peaks.bed
# 01_balbc_intersection_act_peaks.bed
# 01_balbc_intersection_h3k27ac_act_peaks.bed
# 01_balbc_intersectionh3k27ac_act_peaks.bed
# 01_balbc_union_act_peaks.bed
# 01_balbc_union_h3k27ac_act_peaks.bed
# 01_balbc_unionh3k27ac_act_peaks.bed
# 01_c57_intersection_poised_peaks.bed
# 01_c57_union_poised_peaks.bed
# all_peaks.bed
# pu1_all_peaks.bed

# %% [markdown]
# ### label for uploading to UCSC

# %%
with open('./label_bed.sh', 'w') as f:
    for i in glob.glob('./bed_files/*_h3k27ac_act_peaks.bed*'):

        strain = i.split('/')[-1].split('_')[1]
        settype = i.split('/')[-1].split('_')[2]
        group = "Control_Young"
        chip = 'PU1_H3K27Ac_Anno'

        # set track names for upload to ucsc genome browser
        lab = "'track name=\"%s_%s_%s_%s\" description=\"%s %s %s %s ChIP-seq DESeq2 \"'" % (strain, chip, group, settype, strain, group, chip, settype)
        lab_dist = "'track name=\"%s_%s_%s_%s_distal\" description=\"%s %s %s %s ChIP-seq DESeq2 \"'" % (strain, chip, group, settype, strain, group, chip, settype)

        # set labels - can't think of a more clever way to do this so we will just
        # use the simple if / else statement to switch labels depending on our 
        # peak set being distal or all
        
        if 'distal' in i:
            l = lab_dist
        else:
            l = lab
        
        label_track = ['echo', l, '|', 'cat', '-',
                       i,
                       '> temp && mv temp',
                       i, '\n']
    
        f.write(' '.join(label_track))
        
    f.close()

# %% [markdown]
# label all peaks post-hoc

# %%
# %%bash

# echo 'track name="kupffer_control_young_atac_merged" description="Kupffer Young Control ATAC All Strains"' \
# | cat - ./bed_files/all_peaks.bed \
# > temp && mv temp ./bed_files/all_peaks.bed

# %% [markdown]
# # Check bed files and peaks in browser

# %%
# make location column for peak dict (for examining on browser)
diff_peak['location'] = diff_peak.Chr + ':' + diff_peak.Start.map(str) + '-' + diff_peak.End.map(str)

# %%
viz_cols = ['Gene Name', 'Gene Description', 'location', 'Annotation',
            '00_c57 vs. 01_balbc Log2 Fold Change','00_c57 vs. 01_balbc adj. p-value']

# %%
diff_peak_viz = diff_peak.loc[:, viz_cols]

# %%
diff_peak_viz.sort_values(
    '00_c57 vs. 01_balbc adj. p-value', ascending=True).head(40)
# Out:
#                               Gene Name  \
# PeakID
# Merged-chr11-3157651-1         Pisd-ps1
# Merged-chr17-71265855-1         Emilin2
# Merged-chr2-163764576-1             Ada
# Merged-chr17-33980617-1        AA388235
# Merged-chr19-37048725-1           Btaf1
# Merged-chr17-27038478-1          Ggnbp1
# Merged-chr17-36121500-1          H2-T10
# Merged-chr7-16207750-1            Dhx34
# Merged-chr17-27037820-1          Ggnbp1
# Merged-chr13-67778621-1          Zfp493
# Merged-chr17-71257355-1           Lpin2
# Merged-chr17-35749484-2   4833427F10Rik
# Merged-chr2-163765065-2             Ada
# Merged-chr14-30580051-1         Mir3076
# Merged-chr16-93914370-2          Cldn14
# Merged-chr4-133615670-1             Sfn
# Merged-chr15-88128764-1   B230214G05Rik
# Merged-chr4-134094154-1            Cd52
# Merged-chr2-120651816-1           Haus2
# Merged-chr6-134556283-1            Lrp6
# Merged-chr4-6222166-1            Ubxn2b
# Merged-chr1-173961650-2          Ifi203
# Merged-chr17-35750184-1   4833427F10Rik
# Merged-chr5-104860167-1          Zfp951
# Merged-chr9-48418254-1           Gm8884
# Merged-chr19-17276186-1           Gcnt1
# Merged-chr5-147060171-1            Lnx2
# Merged-chr3-127490161-1            Ank2
# Merged-chr14-50820219-1           Parp2
# Merged-chr16-91475862-1          Ifnar1
# Merged-chr10-93945640-2          Mir331
# Merged-chr11-114982107-1        Cd300ld
# Merged-chr7-19077245-1             Dmwd
# Merged-chr8-126779539-1   A630001O12Rik
# Merged-chr10-93967270-1          Mir331
# Merged-chr2-156356174-1   2900097C17Rik
# Merged-chr6-92988413-1    9530026P05Rik
# Merged-chr8-84420729-1          Cacna1a
# Merged-chr15-88128497-1   B230214G05Rik
# Merged-chr17-33981319-1        AA388235
#
#                                                            Gene Description  \
# PeakID
# Merged-chr11-3157651-1       phosphatidylserine decarboxylase, pseudogene 1
# Merged-chr17-71265855-1                    elastin microfibril interfacer 2
# Merged-chr2-163764576-1                                 adenosine deaminase
# Merged-chr17-33980617-1                         expressed sequence AA388235
# Merged-chr19-37048725-1   B-TFIID TATA-box binding protein associated fa...
# Merged-chr17-27038478-1                     gametogenetin binding protein 1
# Merged-chr17-36121500-1             histocompatibility 2, T region locus 10
# Merged-chr7-16207750-1            DEAH (Asp-Glu-Ala-His) box polypeptide 34
# Merged-chr17-27037820-1                     gametogenetin binding protein 1
# Merged-chr13-67778621-1                             zinc finger protein 493
# Merged-chr17-71257355-1                                             lipin 2
# Merged-chr17-35749484-2                          RIKEN cDNA 4833427F10 gene
# Merged-chr2-163765065-2                                 adenosine deaminase
# Merged-chr14-30580051-1                                       microRNA 3076
# Merged-chr16-93914370-2                                          claudin 14
# Merged-chr4-133615670-1                                           stratifin
# Merged-chr15-88128764-1                          RIKEN cDNA B230214G05 gene
# Merged-chr4-134094154-1                                        CD52 antigen
# Merged-chr2-120651816-1                 HAUS augmin-like complex, subunit 2
# Merged-chr6-134556283-1   low density lipoprotein receptor-related prote...
# Merged-chr4-6222166-1                                 UBX domain protein 2B
# Merged-chr1-173961650-2                       interferon activated gene 203
# Merged-chr17-35750184-1                          RIKEN cDNA 4833427F10 gene
# Merged-chr5-104860167-1                             zinc finger protein 951
# Merged-chr9-48418254-1                                  predicted gene 8884
# Merged-chr19-17276186-1       glucosaminyl (N-acetyl) transferase 1, core 2
# Merged-chr5-147060171-1                          ligand of numb-protein X 2
# Merged-chr3-127490161-1                                    ankyrin 2, brain
# Merged-chr14-50820219-1       poly (ADP-ribose) polymerase family, member 2
# Merged-chr16-91475862-1              interferon (alpha and beta) receptor 1
# Merged-chr10-93945640-2                                        microRNA 331
# Merged-chr11-114982107-1                CD300 molecule like family member d
# Merged-chr7-19077245-1      dystrophia myotonica-containing WD repeat motif
# Merged-chr8-126779539-1                          RIKEN cDNA A630001O12 gene
# Merged-chr10-93967270-1                                        microRNA 331
# Merged-chr2-156356174-1                          RIKEN cDNA 2900097C17 gene
# Merged-chr6-92988413-1                           RIKEN cDNA 9530026P05 gene
# Merged-chr8-84420729-1    calcium channel, voltage-dependent, P/Q type, ...
# Merged-chr15-88128497-1                          RIKEN cDNA B230214G05 gene
# Merged-chr17-33981319-1                         expressed sequence AA388235
#
#                                            location  \
# PeakID
# Merged-chr11-3157651-1        chr11:3157151-3158151
# Merged-chr17-71265855-1     chr17:71265355-71266355
# Merged-chr2-163764576-1    chr2:163764076-163765076
# Merged-chr17-33980617-1     chr17:33980117-33981117
# Merged-chr19-37048725-1     chr19:37048225-37049225
# Merged-chr17-27038478-1     chr17:27037978-27038978
# Merged-chr17-36121500-1     chr17:36121000-36122000
# Merged-chr7-16207750-1       chr7:16207250-16208250
# Merged-chr17-27037820-1     chr17:27037320-27038320
# Merged-chr13-67778621-1     chr13:67778121-67779121
# Merged-chr17-71257355-1     chr17:71256855-71257855
# Merged-chr17-35749484-2     chr17:35748983-35749983
# Merged-chr2-163765065-2    chr2:163764554-163765554
# Merged-chr14-30580051-1     chr14:30579551-30580551
# Merged-chr16-93914370-2     chr16:93913878-93914878
# Merged-chr4-133615670-1    chr4:133615170-133616170
# Merged-chr15-88128764-1     chr15:88128264-88129264
# Merged-chr4-134094154-1    chr4:134093654-134094654
# Merged-chr2-120651816-1    chr2:120651316-120652316
# Merged-chr6-134556283-1    chr6:134555783-134556783
# Merged-chr4-6222166-1          chr4:6221666-6222666
# Merged-chr1-173961650-2    chr1:173961146-173962146
# Merged-chr17-35750184-1     chr17:35749684-35750684
# Merged-chr5-104860167-1    chr5:104859667-104860667
# Merged-chr9-48418254-1       chr9:48417754-48418754
# Merged-chr19-17276186-1     chr19:17275686-17276686
# Merged-chr5-147060171-1    chr5:147059671-147060671
# Merged-chr3-127490161-1    chr3:127489661-127490661
# Merged-chr14-50820219-1     chr14:50819719-50820719
# Merged-chr16-91475862-1     chr16:91475362-91476362
# Merged-chr10-93945640-2     chr10:93945143-93946143
# Merged-chr11-114982107-1  chr11:114981607-114982607
# Merged-chr7-19077245-1       chr7:19076745-19077745
# Merged-chr8-126779539-1    chr8:126779039-126780039
# Merged-chr10-93967270-1     chr10:93966770-93967770
# Merged-chr2-156356174-1    chr2:156355674-156356674
# Merged-chr6-92988413-1       chr6:92987913-92988913
# Merged-chr8-84420729-1       chr8:84420229-84421229
# Merged-chr15-88128497-1     chr15:88127997-88128997
# Merged-chr17-33981319-1     chr17:33980819-33981819
#
#                                                      Annotation  \
# PeakID
# Merged-chr11-3157651-1      intron (NM_030207, intron 11 of 32)
# Merged-chr17-71265855-1    intron (NM_001357338, intron 4 of 7)
# Merged-chr2-163764576-1                              Intergenic
# Merged-chr17-33980617-1                promoter-TSS (NR_033305)
# Merged-chr19-37048725-1      intron (NM_198300, intron 9 of 10)
# Merged-chr17-27038478-1                              Intergenic
# Merged-chr17-36121500-1                promoter-TSS (NR_046286)
# Merged-chr7-16207750-1       intron (NM_027883, intron 7 of 16)
# Merged-chr17-27037820-1                              Intergenic
# Merged-chr13-67778621-1                              Intergenic
# Merged-chr17-71257355-1    intron (NM_001357338, intron 4 of 7)
# Merged-chr17-35749484-2                              Intergenic
# Merged-chr2-163765065-2                              Intergenic
# Merged-chr14-30580051-1                              Intergenic
# Merged-chr16-93914370-2                              Intergenic
# Merged-chr4-133615670-1    intron (NM_001017968, intron 2 of 7)
# Merged-chr15-88128764-1                              Intergenic
# Merged-chr4-134094154-1       intron (NM_013706, intron 1 of 1)
# Merged-chr2-120651816-1                              Intergenic
# Merged-chr6-134556283-1      intron (NM_008514, intron 1 of 22)
# Merged-chr4-6222166-1                                Intergenic
# Merged-chr1-173961650-2                         TTS (NM_011940)
# Merged-chr17-35750184-1                              Intergenic
# Merged-chr5-104860167-1             promoter-TSS (NM_001039231)
# Merged-chr9-48418254-1                               Intergenic
# Merged-chr19-17276186-1                              Intergenic
# Merged-chr5-147060171-1       intron (NM_080795, intron 1 of 9)
# Merged-chr3-127490161-1   intron (NM_001327938, intron 1 of 47)
# Merged-chr14-50820219-1     intron (NM_009632, intron 13 of 15)
# Merged-chr16-91475862-1                              Intergenic
# Merged-chr10-93945640-2                              Intergenic
# Merged-chr11-114982107-1                        TTS (NM_145437)
# Merged-chr7-19077245-1        intron (NM_010058, intron 1 of 4)
# Merged-chr8-126779539-1                              Intergenic
# Merged-chr10-93967270-1    3' UTR (NM_001304572, exon 12 of 12)
# Merged-chr2-156356174-1      intron (NM_027585, intron 9 of 12)
# Merged-chr6-92988413-1        intron (NR_015530, intron 1 of 2)
# Merged-chr8-84420729-1    intron (NM_001252060, intron 1 of 47)
# Merged-chr15-88128497-1                              Intergenic
# Merged-chr17-33981319-1                promoter-TSS (NR_033305)
#
#                           00_c57 vs. 01_balbc Log2 Fold Change  \
# PeakID
# Merged-chr11-3157651-1                                4.919846
# Merged-chr17-71265855-1                               4.034952
# Merged-chr2-163764576-1                               4.233201
# Merged-chr17-33980617-1                              -5.254468
# Merged-chr19-37048725-1                              -3.603600
# Merged-chr17-27038478-1                              -5.489164
# Merged-chr17-36121500-1                              -3.529598
# Merged-chr7-16207750-1                               -3.287454
# Merged-chr17-27037820-1                              -5.330975
# Merged-chr13-67778621-1                              -5.202589
# Merged-chr17-71257355-1                               4.753226
# Merged-chr17-35749484-2                              -4.464519
# Merged-chr2-163765065-2                               4.144337
# Merged-chr14-30580051-1                              -3.780351
# Merged-chr16-93914370-2                              -2.997436
# Merged-chr4-133615670-1                               5.579677
# Merged-chr15-88128764-1                               5.773832
# Merged-chr4-134094154-1                              -4.788356
# Merged-chr2-120651816-1                              -3.556197
# Merged-chr6-134556283-1                              -4.714751
# Merged-chr4-6222166-1                                -5.402029
# Merged-chr1-173961650-2                               3.136487
# Merged-chr17-35750184-1                              -4.710600
# Merged-chr5-104860167-1                              -5.234508
# Merged-chr9-48418254-1                               -4.918195
# Merged-chr19-17276186-1                              -6.019919
# Merged-chr5-147060171-1                               4.126191
# Merged-chr3-127490161-1                              -6.184253
# Merged-chr14-50820219-1                              -4.545724
# Merged-chr16-91475862-1                               4.750692
# Merged-chr10-93945640-2                              -3.923624
# Merged-chr11-114982107-1                              4.178006
# Merged-chr7-19077245-1                               -3.959893
# Merged-chr8-126779539-1                              -3.398514
# Merged-chr10-93967270-1                              -4.650738
# Merged-chr2-156356174-1                              -6.038137
# Merged-chr6-92988413-1                                5.715291
# Merged-chr8-84420729-1                                6.753950
# Merged-chr15-88128497-1                               6.865189
# Merged-chr17-33981319-1                              -7.414846
#
#                           00_c57 vs. 01_balbc adj. p-value
# PeakID
# Merged-chr11-3157651-1                        3.598728e-37
# Merged-chr17-71265855-1                       2.662172e-32
# Merged-chr2-163764576-1                       2.977181e-27
# Merged-chr17-33980617-1                       3.944672e-27
# Merged-chr19-37048725-1                       1.057744e-26
# Merged-chr17-27038478-1                       1.432159e-26
# Merged-chr17-36121500-1                       1.432159e-26
# Merged-chr7-16207750-1                        5.095315e-25
# Merged-chr17-27037820-1                       2.372099e-24
# Merged-chr13-67778621-1                       8.541665e-24
# Merged-chr17-71257355-1                       2.916385e-23
# Merged-chr17-35749484-2                       3.384062e-23
# Merged-chr2-163765065-2                       4.076777e-23
# Merged-chr14-30580051-1                       4.162920e-23
# Merged-chr16-93914370-2                       4.272806e-23
# Merged-chr4-133615670-1                       1.119975e-22
# Merged-chr15-88128764-1                       1.702332e-22
# Merged-chr4-134094154-1                       3.641030e-22
# Merged-chr2-120651816-1                       1.235197e-21
# Merged-chr6-134556283-1                       1.235197e-21
# Merged-chr4-6222166-1                         1.474949e-21
# Merged-chr1-173961650-2                       3.089448e-21
# Merged-chr17-35750184-1                       5.643809e-21
# Merged-chr5-104860167-1                       1.498852e-20
# Merged-chr9-48418254-1                        2.018752e-20
# Merged-chr19-17276186-1                       2.018752e-20
# Merged-chr5-147060171-1                       3.937910e-20
# Merged-chr3-127490161-1                       8.875015e-20
# Merged-chr14-50820219-1                       6.338819e-19
# Merged-chr16-91475862-1                       6.853208e-19
# Merged-chr10-93945640-2                       6.853208e-19
# Merged-chr11-114982107-1                      7.173642e-19
# Merged-chr7-19077245-1                        7.279948e-19
# Merged-chr8-126779539-1                       9.086474e-19
# Merged-chr10-93967270-1                       1.130416e-18
# Merged-chr2-156356174-1                       1.272163e-18
# Merged-chr6-92988413-1                        1.307159e-18
# Merged-chr8-84420729-1                        1.792633e-18
# Merged-chr15-88128497-1                       1.792633e-18
# Merged-chr17-33981319-1                       2.048165e-18

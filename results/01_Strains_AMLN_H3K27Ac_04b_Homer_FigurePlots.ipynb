# %% [markdown]
# Hunter Bennett | Kupffer Strains | Glass Lab | 03 Mar 2021
#
# Goal of this notebook is to make figure formatted analyses of homer motif enrichment heatmaps for placement in figures. One outstanding issue is how we will select the TFs to be plotted. Manual curation will probably end up being the strategy.

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('ticks')
# get matplotlib to save readable fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from plotting_scripts import label_point, pca_rpkm_mat, get_diff_volcano
from homer_preprocessing import read_annotated_peaks, import_homer_diffpeak, pull_comparisons_get_diff
from gene_expression_plots import survey_strain_amln_gene_exp, survey_strain_ccl4_gene_exp

# %%
dataDirectory = ''
workingDirectory = '/home/h1bennet/strains/results/01_Strains_AMLN_H3K27Ac/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# # Aggregate results - Homer

# %%
known_motif_pval_frame = pd.read_csv('./homer_known_motifs_log.txt', sep='\t', index_col=0)

# %%
known_motif_pval_frame.sort_values('00_c57_intersection_distal_motifs')
# Out:
#                                                     00_c57_intersection_distal_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                                  -44.17
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                                 -44.02
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                                   -42.78
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer                              -40.12
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...                             -39.94
# ...                                                                               ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                                         0.00
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer                               0.00
# GFX(?)/Promoter/Homer                                                            0.00
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                                   0.00
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                                0.00
#
#                                                     00_c57_intersection_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                       -57.430000
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                      -57.230000
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                        -55.740000
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer                   -50.340000
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...                  -53.110000
# ...                                                                        ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                             -0.031910
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer                   -0.084120
# GFX(?)/Promoter/Homer                                                -0.053070
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                       -0.000017
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                     0.000000
#
#                                                     00_c57_union_distal_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                       -98.550000
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                      -95.140000
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                        -96.190000
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer                   -89.520000
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...                  -91.830000
# ...                                                                        ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                             -0.082140
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer                    0.000000
# GFX(?)/Promoter/Homer                                                -0.679000
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                       -0.001141
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                     0.000000
#
#                                                     00_c57_union_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                -127.60000
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer               -122.70000
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                 -124.40000
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer            -112.20000
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...           -117.90000
# ...                                                                 ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                       -0.10610
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer             -0.05816
# GFX(?)/Promoter/Homer                                          -0.00797
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                  0.00000
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer               0.00000
#
#                                                     01_balbc_intersection_distal_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                                   -0.3884
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                                  -0.1442
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                                    -0.2546
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer                               -0.2324
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...                              -0.2536
# ...                                                                                 ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                                         0.0000
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer                              -0.9697
# GFX(?)/Promoter/Homer                                                            0.0000
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                                   0.0000
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                                0.0000
#
#                                                     01_balbc_intersection_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                           -0.64570
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                          -0.24960
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                            -0.33390
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer                       -0.38710
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...                      -0.45500
# ...                                                                          ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                                -0.08517
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer                      -0.21000
# GFX(?)/Promoter/Homer                                                   -0.21480
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                          -0.01414
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                        0.00000
#
#                                                     01_balbc_union_distal_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                          -0.000018
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                          0.000000
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                           -0.000001
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer                      -0.000017
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...                     -0.000002
# ...                                                                          ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                               -0.015230
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer                     -0.998900
# GFX(?)/Promoter/Homer                                                  -0.924300
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                         -0.019840
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                       0.000000
#
#                                                     01_balbc_union_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                   -0.001065
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                  -0.000023
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                    -0.000019
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer               -0.000418
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...              -0.000160
# ...                                                                   ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                        -0.014210
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer              -0.033240
# GFX(?)/Promoter/Homer                                           -0.040150
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                  -0.000011
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                0.000000
#
#                                                     02_aj_intersection_distal_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                                -0.5308
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                               -0.6103
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                                 -0.6378
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer                            -0.8081
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...                           -0.4326
# ...                                                                              ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                                     -3.0220
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer                            0.0000
# GFX(?)/Promoter/Homer                                                         0.0000
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                                0.0000
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                             0.0000
#
#                                                     02_aj_intersection_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                         -0.8237
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                        -0.8790
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                          -0.9567
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer                     -0.9961
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...                    -0.6640
# ...                                                                       ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                              -1.5170
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer                     0.0000
# GFX(?)/Promoter/Homer                                                  0.0000
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                        -0.1015
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                      0.0000
#
#                                                     02_aj_union_distal_motifs  \
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                        -0.96500
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer                       -1.33900
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                         -0.94040
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer                    -1.16200
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...                   -1.17800
# ...                                                                       ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                             -1.23600
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer                    0.00000
# GFX(?)/Promoter/Homer                                                 0.00000
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer                       -0.02269
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer                     0.00000
#
#                                                     02_aj_union_motifs
# BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer                -0.008456
# Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer               -0.003299
# Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer                 -0.104100
# Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer            -0.000003
# JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE3609...           -0.000008
# ...                                                                ...
# E2F(E2F)/Hela-CellCycle-Expression/Homer                     -0.013340
# ZBTB33(Zf)/GM12878-ZBTB33-ChIP-Seq(GSE32465)/Homer           -0.871700
# GFX(?)/Promoter/Homer                                        -4.207000
# Ronin(THAP)/ES-Thap11-ChIP-Seq(GSE51522)/Homer               -0.238600
# ZFP3(Zf)/HEK293-ZFP3.GFP-ChIP-Seq(GSE58341)/Homer             0.000000
#
# [426 rows x 12 columns]

# %% [markdown]
# # Plot known motif results

# %% [markdown]
# ## Top 10 motifs per comparison

# %% [markdown]
# ### Intersection motifs

# %%
n_motifs = 10
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top10perstrain_intersection_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ### Intersection motifs distal

# %%
n_motifs = 10
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top10perstrain_intersection_enhancers_distal.pdf',
            dpi=300,
            bbox_inches='tight')
plt.close()

# %% [markdown]
# Top 5 per strain

# %%
n_motifs = 5
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    # col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,8))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top5perstrain_intersection_enhancers_distal.pdf',
            dpi=300,
            bbox_inches='tight')
# plt.close()

# %% [markdown]
# ### Union motifs

# %%
n_motifs = 10
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    yticklabels=1,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top10perstrain_union_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ### Union distal enhancers

# %%
n_motifs = 10
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    yticklabels=1,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top10perstrain_union_enhancers_distal.pdf',
            dpi=300,
            bbox_inches='tight')

# %%
n_motifs = 5
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    yticklabels=1,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top5perstrain_union_enhancers_distal.pdf',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ## Option for future: set custom motif list

# %%
motif_list = ['Atf3(bZIP)',
              'AP-1(bZIP)',
              'Mef2c(MADS)',
              'Egr1(Zf)',
              'MITF(bHLH)',
              'COUP-TFII(NR)',
              'bHLHE41(bHLH)',
              'NFkB-p65(RHD)',
              'IRF2(IRF)',
              'ISRE(IRF)']

# %% [markdown]
# ### Intersection enhancers

# %%
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]

#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    fmt='.3g',
    # square=True,
    # center=0,
    # ax=ax,
    # col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    xticklabels=0,
    figsize=(4,10))

plt.savefig('./fancy_figures/homer_enrichedmotifs_custommotifs_intersection_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ### Intersection enhancers distal

# %%
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]

#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=20,
    fmt='.3g',
    # square=True,
    # center=0,
    # ax=ax,
    # col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    xticklabels=0,
    figsize=(4,10))

plt.savefig('./fancy_figures/homer_enrichedmotifs_custommotifs_intersection_distal_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ### Union enhancers

# %%
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]

#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    fmt='.3g',
    # square=True,
    # center=0,
    # ax=ax,
    # col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    xticklabels=0,
    figsize=(4,10))

plt.savefig('./fancy_figures/homer_enrichedmotifs_custommotifs_union_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ### Union distal enhancers

# %%
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]

#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    fmt='.3g',
    # square=True,
    # center=0,
    # ax=ax,
    # col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    xticklabels=0,
    figsize=(4,10))

plt.savefig('./fancy_figures/homer_enrichedmotifs_custommotifs_union_distal_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')

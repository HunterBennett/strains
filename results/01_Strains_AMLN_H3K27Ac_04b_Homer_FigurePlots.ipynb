# %% [markdown]
# Hunter Bennett | Kupffer Strains | Glass Lab | 03 Mar 2021
#
# Goal of this notebook is to make figure formatted analyses of homer motif enrichment heatmaps for placement in figures. One outstanding issue is how we will select the TFs to be plotted. Manual curation will probably end up being the strategy.

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('ticks')
# get matplotlib to save readable fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from plotting_scripts import label_point, pca_rpkm_mat, get_diff_volcano
from homer_preprocessing import read_annotated_peaks, import_homer_diffpeak, pull_comparisons_get_diff
from gene_expression_plots import survey_strain_amln_gene_exp, survey_strain_ccl4_gene_exp

# %%
dataDirectory = ''
workingDirectory = '/home/h1bennet/strains/results/01_Strains_AMLN_H3K27Ac/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# # Aggregate results - Homer

# %%
known_motif_pval_frame = pd.read_csv('./homer_known_motifs_log.txt', sep='\t', index_col=0)

# %%
known_motif_pval_frame.head()
# Out:
#                                                     00_c57_intersection_distal_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                            -6.5930
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                               -2.0740
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                              -3.4910
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                                    -2.0860
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                            -0.2136
#
#                                                     00_c57_intersection_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                     -7.8040
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                        -1.8770
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                       -3.5440
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                             -2.2390
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                     -0.2477
#
#                                                     00_c57_union_distal_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                     -19.380
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                         -3.657
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                       -10.030
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                              -4.424
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                      -0.739
#
#                                                     00_c57_union_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer             -16.6600
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                 -4.2070
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                -6.9300
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                      -5.2050
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer              -0.7662
#
#                                                     01_balbc_intersection_distal_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                               -9.989
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                                  -7.711
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                                -13.320
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                                       -4.644
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                               -4.597
#
#                                                     01_balbc_intersection_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                       -10.440
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                           -7.791
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                         -11.790
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                                -4.448
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                        -4.550
#
#                                                     01_balbc_union_distal_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                        -28.74
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                           -19.98
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                          -19.34
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                                -18.99
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                        -16.00
#
#                                                     01_balbc_union_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                 -28.81
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                    -20.64
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                   -17.28
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                         -18.30
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                 -13.31
#
#                                                     02_aj_intersection_distal_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                          -0.17420
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                             -0.26650
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                            -0.44540
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                                  -0.02712
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                          -0.32700
#
#                                                     02_aj_intersection_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                   -0.03438
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                      -0.29510
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                     -0.17270
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                           -0.06394
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                   -0.71290
#
#                                                     02_aj_union_distal_motifs  \
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer                   -0.41820
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                      -6.42700
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                     -0.01343
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                           -5.45100
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer                   -3.36400
#
#                                                     02_aj_union_motifs
# MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer              -2.858
# COUP-TFII(NR)/K562-NR2F1-ChIP-Seq(Encode)/Homer                 -3.345
# USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer                -2.684
# EAR2(NR)/K562-NR2F6-ChIP-Seq(Encode)/Homer                      -3.253
# COUP-TFII(NR)/Artia-Nr2f2-ChIP-Seq(GSE46497)/Homer              -2.624

# %% [markdown]
# # Plot known motif results

# %% [markdown]
# ## Top 10 motifs per comparison

# %% [markdown]
# ### Intersection motifs

# %%
n_motifs = 10
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top10perstrain_intersection_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ### Intersection motifs distal

# %%
n_motifs = 10
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top10perstrain_intersection_enhancers_distal.pdf',
            dpi=300,
            bbox_inches='tight')
plt.close()

# %% [markdown]
# Top 5 per strain

# %%
n_motifs = 5
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    # col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,8))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top5perstrain_intersection_enhancers_distal.pdf',
            dpi=300,
            bbox_inches='tight')
# plt.close()

# %% [markdown]
# ### Union motifs

# %%
n_motifs = 10
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    yticklabels=1,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top10perstrain_union_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ### Union distal enhancers

# %%
n_motifs = 10
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    yticklabels=1,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top10perstrain_union_enhancers_distal.pdf',
            dpi=300,
            bbox_inches='tight')

# %%
n_motifs = 5
motif_list = []
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

for i in tmp_frame.columns:
    motif_list.extend(tmp_frame.sort_values(i, ascending=True).index.tolist()[:n_motifs])
motif_list = set(motif_list)

sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    yticklabels=1,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_top5perstrain_union_enhancers_distal.pdf',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ## Option for future: set custom motif list

# %%
motif_list = []

# %% [markdown]
# ### Intersection enhancers

# %%
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]
tmp_frame = tmp_frame.loc[motifs, :]

#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_custommotifs_intersection_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-89a0d080b535> in <module>
#       1 tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
#       2 tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]
# ----> 3 tmp_frame = tmp_frame.loc[motifs, :]
#       4
#       5 #clean up rows for tmp frame
#
# NameError: name 'motifs' is not defined

# %% [markdown]
# ### Intersection enhancers distal

# %%
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
tmp_frame = tmp_frame.loc[motifs, :]

#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_custommotifs_intersection_distal_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-64a4f53f2c77> in <module>
#       1 tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('intersection')]
#       2 tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
# ----> 3 tmp_frame = tmp_frame.loc[motifs, :]
#       4
#       5 #clean up rows for tmp frame
#
# NameError: name 'motifs' is not defined

# %% [markdown]
# ### Union enhancers

# %%
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]
tmp_frame = tmp_frame.loc[motifs, :]

#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    vmax=50,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_custommotifs_union_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8ce7dd25cbf3> in <module>
#       1 tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
#       2 tmp_frame = tmp_frame.loc[:, ~tmp_frame.columns.str.contains('distal')]
# ----> 3 tmp_frame = tmp_frame.loc[motifs, :]
#       4
#       5 #clean up rows for tmp frame
#
# NameError: name 'motifs' is not defined

# %% [markdown]
# ### Union distal enhancers

# %%
tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
tmp_frame = tmp_frame.loc[motifs, :]

#clean up rows for tmp frame
tmp_frame.index = tmp_frame.index.str.split('/').str[0]

cm = sns.clustermap(
    -tmp_frame.loc[motif_list, :],
    cmap='Reds',
    # linewidths=1,
    # linecolor='k',
    # annot=True,
    cbar_kws={'label': '-log10(pval)'},
    col_cluster=False,
    # square=True,
    # center=0,
    # ax=ax,
    col_colors=['#31a354', '#3182bd', '#de2d26'],
    yticklabels=1,
    figsize=(3,12.5))

plt.savefig('./fancy_figures/homer_enrichedmotifs_custommotifs_union_distal_enhancers.pdf',
            dpi=300,
            bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-26769ef089d6> in <module>
#       1 tmp_frame = known_motif_pval_frame.loc[:, known_motif_pval_frame.columns.str.contains('union')]
#       2 tmp_frame = tmp_frame.loc[:, tmp_frame.columns.str.contains('distal')]
# ----> 3 tmp_frame = tmp_frame.loc[motifs, :]
#       4
#       5 #clean up rows for tmp frame
#
# NameError: name 'motifs' is not defined
